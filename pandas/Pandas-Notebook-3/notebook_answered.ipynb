# %% [markdown]
# # 450+ Practice Questions That Will Make You a Pandas, NumPy, and SQL Pro!

# %% [markdown]
# Author: Avi Chawla
#
# LinkedIn: https://www.linkedin.com/in/avi-chawla/
#
# Read my blogs here: https://medium.com/@avi_chawla

# %% [markdown]
# ## Introduction

# %% [markdown]
# This notebook has been created for you to practice three of the most common tools used in building any machine learning or data science applications, i.e., Pandas, NumPy, and SQL!

# %% [markdown]
# The practice questions provided will serve as a great resource for those who are looking to familiarize themselves with some of the most common functions used in these tools.

# %% [markdown]
# Appropriate descriptions have been provided for all the questions in this entire exercise which will help you navigate through this exercise easily. If a dataset is to be loaded in the python environment, that has also been provided for you. You can find it on the right panel in the Files section. Do NOT delete any of the files/folders listed there.

# %% [markdown]
# The whole exercise has been divided into nine separate notebooks. Below are the links to all the other notebooks for you to jump from one notebook to another:

# %% [markdown]
# - **Pandas**
#
# 1. Pandas Notebook 1: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-Notebook-1-d693ac55-6455-40cf-ae34-867c6a02014e/%2Fnotebook.ipynb)
# 2. Pandas Notebook 2: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-Notebook-employee-dataset-7e3b6755-5d4b-464b-9b75-9c84667ae3bd/%2Fnotebook.ipynb)
#
# 3. Pandas Notebook 3: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-Notebook-employee-part-2-adc5a3ee-5f61-4725-8e46-ccb07899acfc/%2Fnotebook.ipynb) **(This Notebook)**
#
# 4. Pandas Notebook 4: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-after-employee-f84e02a1-fb6a-428e-af90-8dd99855749a/%2Fnotebook.ipynb)
#
# - **NumPy**
#
# 1. NumPy Notebook 1: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Numpy-part-1-9b9979f2-b708-4292-b466-3d0157564c91/%2Fnotebook.ipynb)
#
# 2. NumPy Notebook 2: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/NumPy-Notebook-2-4456411e-2ddd-426d-8027-4881080027db/%2Fnotebook.ipynb)
#
# 3. NumPy Notebook 3: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/NumPy-Notebook-3-e6587114-b580-4249-b599-540de859e603/%2Fnotebook.ipynb)
#
# - **SQL**
#
# 1. SQL Notebook 1: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/SQL-Notebook-1-eac9d782-a9b1-4e84-a1f9-af14080a6121/%2Fnotebook.ipynb)
#
# 2. SQL Notebook 2: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/SQL-Notebook-2-1914b214-be03-44a1-be63-ad99e98be639/%2Fnotebook.ipynb)

# %% [markdown]
# ## How to use this notebook?

# %% [markdown]
# At the top right corner, you will find a Duplicate button. This will allow you to create a unique notebook for your own practice and write solutions to the question listed in this notebook.

# %% [markdown]
# If you face any issues or have any feedback, feel free to reach out to me (Avi Chawla) either on Linkedin: https://www.linkedin.com/in/avi-chawla/ or write an email to avi@dsscholar[dot]com.

# %% [markdown]
# Let's begin 🚀!

# %% [markdown]
# # Pandas Notebook 3

# %%
import pandas as pd

# %%
data = pd.read_csv("employee_dataset.csv")
data.head()
# Out:
#              Name                  Company_Name  \
# 0  Spencer Adkins                James and Sons
# 1    Julie Morton                 Nichols-James
# 2    Matthew Hall                     Scott Inc
# 3      Brad Scott  Johnston, Fleming and Tanner
# 4   Theresa Owens      Baker, Allen and Edwards
#
#                         Employee_Job_Title      Employee_City  \
# 0                          Equities trader     New Russellton
# 1  Diplomatic Services operational officer  North Melissafurt
# 2               Regulatory affairs officer           Wardfort
# 3                      Production engineer     West Jamesview
# 4                      Production engineer          Whiteside
#
#         Employee_Country  Employee_Salary Employment_Status  Employee_Rating
# 0  Palestinian Territory           321520         Full Time              3.9
# 1       Marshall Islands           589090         Full Time              4.3
# 2               Anguilla           630890         Full Time              3.1
# 3   Syrian Arab Republic           116400         Full Time              3.1
# 4               Dominica           523499         Full Time              4.8

# %% [markdown]
# ### 91. What is the ratio of total full-time employees to Interns?

# %%
data.query("Employment_Status == 'Full Time'").shape[0] / data.query("Employment_Status == 'Intern'").shape[0]
# Out:
# 4.0008334722453744

# %% [markdown]
# ### 92. Starting from the first record, print every third record in the DataFrame.

# %% [markdown]
# Print 1st row, then 4th, 7th, 10th, and so on...

# %%
data.iloc[::3, :]
# Out:
#                      Name                    Company_Name  \
# 0          Spencer Adkins                  James and Sons
# 3              Brad Scott    Johnston, Fleming and Tanner
# 6             Kelly Brown                     Andrade LLC
# 9         Michael Edwards  Campos, Reynolds and Mccormick
# 12         Tiffany Galvan  Campos, Reynolds and Mccormick
# ...                   ...                             ...
# 299985      Chase Stevens                       Nelson-Li
# 299988     Kenneth Hurley                       Scott Inc
# 299991  William Rodriguez                       Scott Inc
# 299994      Kelly Bennett         White, Mcclain and Cobb
# 299997        Lynn Wilson                   Nichols-James
#
#                              Employee_Job_Title     Employee_City  \
# 0                               Equities trader    New Russellton
# 3                           Production engineer    West Jamesview
# 6                               Naval architect          Wardfort
# 9                                    Ergonomist  New Cindychester
# 12      Diplomatic Services operational officer    West Jamesview
# ...                                         ...               ...
# 299985                           Energy manager      Whitakerbury
# 299988                                     Make    New Russellton
# 299991                               Ergonomist         Whiteside
# 299994                Radiographer, therapeutic          Wardfort
# 299997                            Administrator  New Cindychester
#
#                         Employee_Country  Employee_Salary Employment_Status  \
# 0                  Palestinian Territory           321520         Full Time
# 3                   Syrian Arab Republic           116400         Full Time
# 6                                  Aruba           711410         Full Time
# 9       Lao People's Democratic Republic           516950         Full Time
# 12                                 Niger           786430            Intern
# ...                                  ...              ...               ...
# 299985          Northern Mariana Islands           590590         Full Time
# 299988                Russian Federation           211180         Full Time
# 299991                       New Zealand           214400         Full Time
# 299994                              Fiji           182270         Full Time
# 299997                           Bolivia           802830         Full Time
#
#         Employee_Rating
# 0                   3.9
# 3                   3.1
# 6                   2.0
# 9                   2.3
# 12                  3.6
# ...                 ...
# 299985              2.6
# 299988              3.9
# 299991              1.5
# 299994              3.6
# 299997              0.6
#
# [100000 rows x 8 columns]

# %% [markdown]
# ### 93. Find the average salary for every company.

# %%
data[["Company_Name", "Employee_Salary"]].groupby("Company_Name").mean()
# Out:
#                                 Employee_Salary
# Company_Name
# Andrade LLC                       497237.159385
# Baker, Allen and Edwards          498032.358445
# Bullock-Carrillo                  499603.804865
# Campos, Reynolds and Mccormick    503528.982687
# James and Sons                    503581.015754
# Johnston, Fleming and Tanner      500579.128010
# Marshall-Holloway                 502314.169445
# Matthews Inc                      501640.159488
# Nelson-Li                         500569.824558
# Nichols-James                     497881.232334
# Scott Inc                         500491.809024
# Taylor-Ramos                      498747.292516
# Thomas-Spencer                    499350.850164
# Wallace, Smith and Shepard        500807.608810
# White, Mcclain and Cobb           499083.493806

# %% [markdown]
# ### 94. Find the average rating for every company.

# %%
data[["Company_Name", "Employee_Rating"]].groupby("Company_Name").mean()
# Out:
#                                 Employee_Rating
# Company_Name
# Andrade LLC                            2.498218
# Baker, Allen and Edwards               2.504795
# Bullock-Carrillo                       2.502014
# Campos, Reynolds and Mccormick         2.506288
# James and Sons                         2.505023
# Johnston, Fleming and Tanner           2.513159
# Marshall-Holloway                      2.504900
# Matthews Inc                           2.525454
# Nelson-Li                              2.504649
# Nichols-James                          2.488554
# Scott Inc                              2.515993
# Taylor-Ramos                           2.513150
# Thomas-Spencer                         2.505114
# Wallace, Smith and Shepard             2.497402
# White, Mcclain and Cobb                2.504047

# %% [markdown]
# ### 95. Find the average salary and average rating for every company in a single line.

# %%
data[["Company_Name", "Employee_Salary", "Employee_Rating"]].groupby("Company_Name").mean()
# Out:
#                                 Employee_Salary  Employee_Rating
# Company_Name
# Andrade LLC                       497237.159385         2.498218
# Baker, Allen and Edwards          498032.358445         2.504795
# Bullock-Carrillo                  499603.804865         2.502014
# Campos, Reynolds and Mccormick    503528.982687         2.506288
# James and Sons                    503581.015754         2.505023
# Johnston, Fleming and Tanner      500579.128010         2.513159
# Marshall-Holloway                 502314.169445         2.504900
# Matthews Inc                      501640.159488         2.525454
# Nelson-Li                         500569.824558         2.504649
# Nichols-James                     497881.232334         2.488554
# Scott Inc                         500491.809024         2.515993
# Taylor-Ramos                      498747.292516         2.513150
# Thomas-Spencer                    499350.850164         2.505114
# Wallace, Smith and Shepard        500807.608810         2.497402
# White, Mcclain and Cobb           499083.493806         2.504047

# %% [markdown]
# ### 96. Find the number of unique Employee_City corresponding to every Company_Name.

# %%
data[["Company_Name", "Employee_City"]].groupby("Company_Name").nunique()
# Out:
#                                 Employee_City
# Company_Name
# Andrade LLC                                10
# Baker, Allen and Edwards                   10
# Bullock-Carrillo                           10
# Campos, Reynolds and Mccormick             10
# James and Sons                             10
# Johnston, Fleming and Tanner               10
# Marshall-Holloway                          10
# Matthews Inc                               10
# Nelson-Li                                  10
# Nichols-James                              10
# Scott Inc                                  10
# Taylor-Ramos                               10
# Thomas-Spencer                             10
# Wallace, Smith and Shepard                 10
# White, Mcclain and Cobb                    10

# %% [markdown]
# ### 98. Print the number of full-time and intern employees for every company

# %%
data[["Company_Name", "Employment_Status"]].groupby(["Company_Name", "Employment_Status"]).size().reset_index(name='counts')
# Out:
#                       Company_Name Employment_Status  counts
# 0                      Andrade LLC         Full Time   15964
# 1                      Andrade LLC            Intern    4019
# 2         Baker, Allen and Edwards         Full Time   16118
# 3         Baker, Allen and Edwards            Intern    3966
# 4                 Bullock-Carrillo         Full Time   16135
# 5                 Bullock-Carrillo            Intern    3928
# 6   Campos, Reynolds and Mccormick         Full Time   15930
# 7   Campos, Reynolds and Mccormick            Intern    3997
# 8                   James and Sons         Full Time   15888
# 9                   James and Sons            Intern    3980
# 10    Johnston, Fleming and Tanner         Full Time   15832
# 11    Johnston, Fleming and Tanner            Intern    3979
# 12               Marshall-Holloway         Full Time   15871
# 13               Marshall-Holloway            Intern    3988
# 14                    Matthews Inc         Full Time   16082
# 15                    Matthews Inc            Intern    4001
# 16                       Nelson-Li         Full Time   16027
# 17                       Nelson-Li            Intern    4105
# 18                   Nichols-James         Full Time   15872
# 19                   Nichols-James            Intern    4039
# 20                       Scott Inc         Full Time   16396
# 21                       Scott Inc            Intern    3994
# 22                    Taylor-Ramos         Full Time   16086
# 23                    Taylor-Ramos            Intern    4036
# 24                  Thomas-Spencer         Full Time   16037
# 25                  Thomas-Spencer            Intern    4105
# 26      Wallace, Smith and Shepard         Full Time   15467
# 27      Wallace, Smith and Shepard            Intern    3897
# 28         White, Mcclain and Cobb         Full Time   16305
# 29         White, Mcclain and Cobb            Intern    3956

# %% [markdown]
# ### 99. Print the job title with the most employees.

# %%
data.value_counts("Employee_Job_Title").index[0]
# Out:
# 'Diplomatic Services operational officer'

# %% [markdown]
# ### 100. Print the job title with the most employees corresponding to every company.

# %%
temp = data[["Company_Name", "Employee_Job_Title"]].groupby(["Company_Name", "Employee_Job_Title"]).size().reset_index(name='counts')
temp.groupby(["Company_Name"]).max()
# Out:
#                                        Employee_Job_Title  counts
# Company_Name
# Andrade LLC                     Trading standards officer    2016
# Baker, Allen and Edwards        Trading standards officer    1988
# Bullock-Carrillo                Trading standards officer    2025
# Campos, Reynolds and Mccormick  Trading standards officer    2025
# James and Sons                  Trading standards officer    1953
# Johnston, Fleming and Tanner    Trading standards officer    2053
# Marshall-Holloway               Trading standards officer    1961
# Matthews Inc                    Trading standards officer    2032
# Nelson-Li                       Trading standards officer    1964
# Nichols-James                   Trading standards officer    2088
# Scott Inc                       Trading standards officer    2003
# Taylor-Ramos                    Trading standards officer    2056
# Thomas-Spencer                  Trading standards officer    2065
# Wallace, Smith and Shepard      Trading standards officer    1929
# White, Mcclain and Cobb         Trading standards officer    1979

# %% [markdown]
# ### 101. Find the average salary for corresponding to every value of 'Employment_Status'

# %%
data[["Employment_Status", "Employee_Salary"]].groupby("Employment_Status").mean()
# Out:
#                    Employee_Salary
# Employment_Status
# Full Time            500202.359368
# Intern               500311.619370

# %% [markdown]
# ### 102. Print the index corresponding to the maximum Employee_Salary

# %%
data["Employee_Salary"].sort_values().index[-1]
# Out:
# 70356

# %% [markdown]
# ### 103. How many unique firstnames exist in the dataset?

# %%
temp = data[["Name"]].copy()
temp[["first", "last"]] = temp["Name"].str.split(expand=True)
temp["first"].nunique()
# Out:
# 690

# %% [markdown]
# ### 104. How many unique lastnames exist in the dataset?

# %%
temp["last"].nunique()
# Out:
# 1000

# %% [markdown]
# ### 105. How many unique firstnames exist in the dataset for every company?

# %%
temp = data[["Company_Name", "Name"]].copy()
temp[["first", "last"]] = temp["Name"].str.split(expand=True)
temp[["Company_Name", "first"]].groupby("Company_Name").nunique("first")
# Out:
#                                 first
# Company_Name
# Andrade LLC                       686
# Baker, Allen and Edwards          686
# Bullock-Carrillo                  687
# Campos, Reynolds and Mccormick    682
# James and Sons                    683
# Johnston, Fleming and Tanner      683
# Marshall-Holloway                 686
# Matthews Inc                      687
# Nelson-Li                         683
# Nichols-James                     684
# Scott Inc                         689
# Taylor-Ramos                      689
# Thomas-Spencer                    687
# Wallace, Smith and Shepard        681
# White, Mcclain and Cobb           686

# %% [markdown]
# ### 106. Are there any rows for the employee name 'Michael Edward'? Print True or False

# %%
'Michael Edward' in data["Name"].tolist()
# Out:
# False

# %% [markdown]
# ### 107. Check if the substring 'Michael Edward' appears in the Name column or not.

# %%
data["Name"].str.contains("Michael" or "Edward").any()
# Out:
# True

# %% [markdown]
# ### 108. How many unique Job titles start with the substring 'Pr' (case-sensitive matching)

# %%
data[data["Employee_Job_Title"].str.startswith("Pr")]["Employee_Job_Title"].unique()
# Out:
# array(['Production engineer'], dtype=object)

# %% [markdown]
# ### 109. How many unique Job titles start with the substring 'Pr' (case-insensitive matching)

# %%
data[data["Employee_Job_Title"].str.lower().str.startswith("pr")]["Employee_Job_Title"].unique()
# Out:
# array(['Production engineer'], dtype=object)

# %% [markdown]
# ### 109. How many records are there whose Country end with the substring 'urt' (case-insensitive matching)

# %%
data["Employee_Country"].str.lower().str.endswith("urt").sum()
# Out:
# 0

# %% [markdown]
# ### 110. Print the number of records whose company name contains the substring 'LL' (case-insensitive).

# %%
data["Employee_Country"].str.upper().str.contains("LL").sum()
# Out:
# 6204

# %% [markdown]
# ### 111. Select the first row corresponding to every company in the dataframe

# %%
data.drop_duplicates(subset="Company_Name", keep="first")
# Out:
#                   Name                    Company_Name  \
# 0       Spencer Adkins                  James and Sons
# 1         Julie Morton                   Nichols-James
# 2         Matthew Hall                       Scott Inc
# 3           Brad Scott    Johnston, Fleming and Tanner
# 4        Theresa Owens        Baker, Allen and Edwards
# 5        Vanessa Allen                     Andrade LLC
# 7          Vicki Beard                    Matthews Inc
# 8          Lisa French                    Taylor-Ramos
# 9      Michael Edwards  Campos, Reynolds and Mccormick
# 10     Victoria Sutton         White, Mcclain and Cobb
# 17           Gail Rose                  Thomas-Spencer
# 18        Carrie Woods                Bullock-Carrillo
# 25      David Phillips               Marshall-Holloway
# 45        Ronald Clark      Wallace, Smith and Shepard
# 61  Micheal Fitzgerald                       Nelson-Li
#
#                          Employee_Job_Title      Employee_City  \
# 0                           Equities trader     New Russellton
# 1   Diplomatic Services operational officer  North Melissafurt
# 2                Regulatory affairs officer           Wardfort
# 3                       Production engineer     West Jamesview
# 4                       Production engineer          Whiteside
# 5                                      Make       Ricardomouth
# 7   Diplomatic Services operational officer        Kristaburgh
# 8                 Radiographer, therapeutic     West Jamesview
# 9                                Ergonomist   New Cindychester
# 10                          Naval architect          Whiteside
# 17                          Patent examiner       Whitakerbury
# 18                               Ergonomist     New Russellton
# 25                Radiographer, therapeutic        Kristaburgh
# 45               Regulatory affairs officer  North Melissafurt
# 61  Diplomatic Services operational officer       Whitakerbury
#
#                     Employee_Country  Employee_Salary Employment_Status  \
# 0              Palestinian Territory           321520         Full Time
# 1                   Marshall Islands           589090         Full Time
# 2                           Anguilla           630890         Full Time
# 3               Syrian Arab Republic           116400         Full Time
# 4                           Dominica           523499         Full Time
# 5                               Mali           850140         Full Time
# 7                     Western Sahara           777000         Full Time
# 8                             Kuwait           870580         Full Time
# 9   Lao People's Democratic Republic           516950         Full Time
# 10                            Poland           656260         Full Time
# 17                           Finland           178570         Full Time
# 18                             Gabon           985290         Full Time
# 25            British Virgin Islands            58800         Full Time
# 45                             Palau           914110         Full Time
# 61                       Switzerland           796690         Full Time
#
#     Employee_Rating
# 0               3.9
# 1               4.3
# 2               3.1
# 3               3.1
# 4               4.8
# 5               2.6
# 7               3.3
# 8               1.3
# 9               2.3
# 10              4.9
# 17              1.9
# 18              2.4
# 25              0.6
# 45              3.2
# 61              4.1

# %% [markdown]
# ### 112. Select the last row corresponding to every company in the dataframe

# %%
data.drop_duplicates(subset="Company_Name", keep="last")
# Out:
#                      Name                    Company_Name  \
# 299953   Elizabeth Carter                    Taylor-Ramos
# 299966        Sarah Parks               Marshall-Holloway
# 299978      Melissa Blair                    Matthews Inc
# 299983     William Jensen                  Thomas-Spencer
# 299985      Chase Stevens                       Nelson-Li
# 299986        Chelsea Lee                     Andrade LLC
# 299987         Lori Chang  Campos, Reynolds and Mccormick
# 299990      Monica Bender      Wallace, Smith and Shepard
# 299991  William Rodriguez                       Scott Inc
# 299992    Steven Thornton        Baker, Allen and Edwards
# 299994      Kelly Bennett         White, Mcclain and Cobb
# 299995         Nancy Neal                Bullock-Carrillo
# 299996     Michele Butler    Johnston, Fleming and Tanner
# 299998      Lindsey Keith                   Nichols-James
# 299999      Karen Delgado                  James and Sons
#
#                        Employee_Job_Title      Employee_City  \
# 299953         Regulatory affairs officer     West Jamesview
# 299966                         Ergonomist   New Cindychester
# 299978          Radiographer, therapeutic          Whiteside
# 299983  Sales promotion account executive  North Melissafurt
# 299985                     Energy manager       Whitakerbury
# 299986       Investment banker, corporate           Wardfort
# 299987                    Naval architect   New Cindychester
# 299990                Production engineer   New Cindychester
# 299991                         Ergonomist          Whiteside
# 299992                    Patent examiner         Aliciafort
# 299994          Radiographer, therapeutic           Wardfort
# 299995                        Optometrist  North Melissafurt
# 299996                      Administrator         Aliciafort
# 299998                               Make       Whitakerbury
# 299999                            Actuary     New Russellton
#
#                         Employee_Country  Employee_Salary Employment_Status  \
# 299953                      Turkmenistan           629680         Full Time
# 299966            Libyan Arab Jamahiriya           793670            Intern
# 299978  Lao People's Democratic Republic           455410         Full Time
# 299983                Russian Federation           637780            Intern
# 299985          Northern Mariana Islands           590590         Full Time
# 299986                       Switzerland            88410         Full Time
# 299987                             Japan           723370            Intern
# 299990                        Bangladesh           852660         Full Time
# 299991                       New Zealand           214400         Full Time
# 299992                             Benin            60240         Full Time
# 299994                              Fiji           182270         Full Time
# 299995                             Samoa            99670            Intern
# 299996                              Cuba           949580            Intern
# 299998                    Western Sahara           257240         Full Time
# 299999                    United Kingdom           575770            Intern
#
#         Employee_Rating
# 299953              4.0
# 299966              2.0
# 299978              1.3
# 299983              1.6
# 299985              2.6
# 299986              4.4
# 299987              4.0
# 299990              3.0
# 299991              1.5
# 299992              4.3
# 299994              3.6
# 299995              3.3
# 299996              2.6
# 299998              2.4
# 299999              3.3

# %% [markdown]
# ### 113. Reset the index of the dataframe inplace and delete the older index values.

# %%
data.reset_index(inplace=True, drop=True)
data
# Out:
#                   Name                  Company_Name  \
# 0       Spencer Adkins                James and Sons
# 1         Julie Morton                 Nichols-James
# 2         Matthew Hall                     Scott Inc
# 3           Brad Scott  Johnston, Fleming and Tanner
# 4        Theresa Owens      Baker, Allen and Edwards
# ...                ...                           ...
# 299995      Nancy Neal              Bullock-Carrillo
# 299996  Michele Butler  Johnston, Fleming and Tanner
# 299997     Lynn Wilson                 Nichols-James
# 299998   Lindsey Keith                 Nichols-James
# 299999   Karen Delgado                James and Sons
#
#                              Employee_Job_Title      Employee_City  \
# 0                               Equities trader     New Russellton
# 1       Diplomatic Services operational officer  North Melissafurt
# 2                    Regulatory affairs officer           Wardfort
# 3                           Production engineer     West Jamesview
# 4                           Production engineer          Whiteside
# ...                                         ...                ...
# 299995                              Optometrist  North Melissafurt
# 299996                            Administrator         Aliciafort
# 299997                            Administrator   New Cindychester
# 299998                                     Make       Whitakerbury
# 299999                                  Actuary     New Russellton
#
#              Employee_Country  Employee_Salary Employment_Status  \
# 0       Palestinian Territory           321520         Full Time
# 1            Marshall Islands           589090         Full Time
# 2                    Anguilla           630890         Full Time
# 3        Syrian Arab Republic           116400         Full Time
# 4                    Dominica           523499         Full Time
# ...                       ...              ...               ...
# 299995                  Samoa            99670            Intern
# 299996                   Cuba           949580            Intern
# 299997                Bolivia           802830         Full Time
# 299998         Western Sahara           257240         Full Time
# 299999         United Kingdom           575770            Intern
#
#         Employee_Rating
# 0                   3.9
# 1                   4.3
# 2                   3.1
# 3                   3.1
# 4                   4.8
# ...                 ...
# 299995              3.3
# 299996              2.6
# 299997              0.6
# 299998              2.4
# 299999              3.3
#
# [300000 rows x 8 columns]

# %% [markdown]
# ### 114. Print the type of the DataFrame object.

# %%
data.dtypes
# Out:
# Name                   object
# Company_Name           object
# Employee_Job_Title     object
# Employee_City          object
# Employee_Country       object
# Employee_Salary         int64
# Employment_Status      object
# Employee_Rating       float64
# dtype: object

# %% [markdown]
# ### 115. Add a new row at the bottom of the DataFrame.

# %%
new_row = ["Chris Anders", "Scott Inc", "Production engineer", "Wardfort", "Anguilla", 343930, "Full Time", 3.3]
data = data.append(pd.DataFrame(new_row, index=data.columns).T, ignore_index=True)
data
# Out:
#                   Name                  Company_Name  \
# 0       Spencer Adkins                James and Sons
# 1         Julie Morton                 Nichols-James
# 2         Matthew Hall                     Scott Inc
# 3           Brad Scott  Johnston, Fleming and Tanner
# 4        Theresa Owens      Baker, Allen and Edwards
# ...                ...                           ...
# 299996  Michele Butler  Johnston, Fleming and Tanner
# 299997     Lynn Wilson                 Nichols-James
# 299998   Lindsey Keith                 Nichols-James
# 299999   Karen Delgado                James and Sons
# 300000    Chris Anders                     Scott Inc
#
#                              Employee_Job_Title      Employee_City  \
# 0                               Equities trader     New Russellton
# 1       Diplomatic Services operational officer  North Melissafurt
# 2                    Regulatory affairs officer           Wardfort
# 3                           Production engineer     West Jamesview
# 4                           Production engineer          Whiteside
# ...                                         ...                ...
# 299996                            Administrator         Aliciafort
# 299997                            Administrator   New Cindychester
# 299998                                     Make       Whitakerbury
# 299999                                  Actuary     New Russellton
# 300000                      Production engineer           Wardfort
#
#              Employee_Country Employee_Salary Employment_Status  \
# 0       Palestinian Territory          321520         Full Time
# 1            Marshall Islands          589090         Full Time
# 2                    Anguilla          630890         Full Time
# 3        Syrian Arab Republic          116400         Full Time
# 4                    Dominica          523499         Full Time
# ...                       ...             ...               ...
# 299996                   Cuba          949580            Intern
# 299997                Bolivia          802830         Full Time
# 299998         Western Sahara          257240         Full Time
# 299999         United Kingdom          575770            Intern
# 300000               Anguilla          343930         Full Time
#
#        Employee_Rating
# 0                  3.9
# 1                  4.3
# 2                  3.1
# 3                  3.1
# 4                  4.8
# ...                ...
# 299996             2.6
# 299997             0.6
# 299998             2.4
# 299999             3.3
# 300000             3.3
#
# [300001 rows x 8 columns]

# %% [markdown]
# ### 116. Print the new shape of the DataFrame.

# %%
data.shape
# Out:
# (300001, 8)

# %% [markdown]
# ### 117. Add a new column "Employee_Rating_New" which should be as follows:

# %% [markdown]
# Employee_Rating_New = max(1.5, 2*Employee_Rating - 3)

# %%
import numpy as np

# %%
data["Employee_Rating_New"] = np.maximum(1.5, 2*data["Employee_Rating"]-3)
data
# Out:
#                   Name                  Company_Name  \
# 0       Spencer Adkins                James and Sons
# 1         Julie Morton                 Nichols-James
# 2         Matthew Hall                     Scott Inc
# 3           Brad Scott  Johnston, Fleming and Tanner
# 4        Theresa Owens      Baker, Allen and Edwards
# ...                ...                           ...
# 299996  Michele Butler  Johnston, Fleming and Tanner
# 299997     Lynn Wilson                 Nichols-James
# 299998   Lindsey Keith                 Nichols-James
# 299999   Karen Delgado                James and Sons
# 300000    Chris Anders                     Scott Inc
#
#                              Employee_Job_Title      Employee_City  \
# 0                               Equities trader     New Russellton
# 1       Diplomatic Services operational officer  North Melissafurt
# 2                    Regulatory affairs officer           Wardfort
# 3                           Production engineer     West Jamesview
# 4                           Production engineer          Whiteside
# ...                                         ...                ...
# 299996                            Administrator         Aliciafort
# 299997                            Administrator   New Cindychester
# 299998                                     Make       Whitakerbury
# 299999                                  Actuary     New Russellton
# 300000                      Production engineer           Wardfort
#
#              Employee_Country Employee_Salary Employment_Status  \
# 0       Palestinian Territory          321520         Full Time
# 1            Marshall Islands          589090         Full Time
# 2                    Anguilla          630890         Full Time
# 3        Syrian Arab Republic          116400         Full Time
# 4                    Dominica          523499         Full Time
# ...                       ...             ...               ...
# 299996                   Cuba          949580            Intern
# 299997                Bolivia          802830         Full Time
# 299998         Western Sahara          257240         Full Time
# 299999         United Kingdom          575770            Intern
# 300000               Anguilla          343930         Full Time
#
#        Employee_Rating Employee_Rating_New
# 0                  3.9                 4.8
# 1                  4.3                 5.6
# 2                  3.1                 3.2
# 3                  3.1                 3.2
# 4                  4.8                 6.6
# ...                ...                 ...
# 299996             2.6                 2.2
# 299997             0.6                 1.5
# 299998             2.4                 1.8
# 299999             3.3                 3.6
# 300000             3.3                 3.6
#
# [300001 rows x 9 columns]

# %% [markdown]
# ### 118. Convert the entire DataFrame to a list of lists. Do NOT overwrite to the current dataframe object.

# %%
df_list = data.values.tolist()
df_list[0:3]
# Out:
# [['Spencer Adkins',
#   'James and Sons',
#   'Equities trader',
#   'New Russellton',
#   'Palestinian Territory',
#   321520,
#   'Full Time',
#   3.9,
#   4.8],
#  ['Julie Morton',
#   'Nichols-James',
#   'Diplomatic Services operational officer',
#   'North Melissafurt',
#   'Marshall Islands',
#   589090,
#   'Full Time',
#   4.3,
#   5.6],
#  ['Matthew Hall',
#   'Scott Inc',
#   'Regulatory affairs officer',
#   'Wardfort',
#   'Anguilla',
#   630890,
#   'Full Time',
#   3.1,
#   3.2]]

# %% [markdown]
# ### 119. Convert the 'Name' to upper case and store it back to the same column.

# %%
df = data.rename(columns={"Name": "NAME"})
df
# Out:
#                   NAME                  Company_Name  \
# 0       Spencer Adkins                James and Sons
# 1         Julie Morton                 Nichols-James
# 2         Matthew Hall                     Scott Inc
# 3           Brad Scott  Johnston, Fleming and Tanner
# 4        Theresa Owens      Baker, Allen and Edwards
# ...                ...                           ...
# 299996  Michele Butler  Johnston, Fleming and Tanner
# 299997     Lynn Wilson                 Nichols-James
# 299998   Lindsey Keith                 Nichols-James
# 299999   Karen Delgado                James and Sons
# 300000    Chris Anders                     Scott Inc
#
#                              Employee_Job_Title      Employee_City  \
# 0                               Equities trader     New Russellton
# 1       Diplomatic Services operational officer  North Melissafurt
# 2                    Regulatory affairs officer           Wardfort
# 3                           Production engineer     West Jamesview
# 4                           Production engineer          Whiteside
# ...                                         ...                ...
# 299996                            Administrator         Aliciafort
# 299997                            Administrator   New Cindychester
# 299998                                     Make       Whitakerbury
# 299999                                  Actuary     New Russellton
# 300000                      Production engineer           Wardfort
#
#              Employee_Country Employee_Salary Employment_Status  \
# 0       Palestinian Territory          321520         Full Time
# 1            Marshall Islands          589090         Full Time
# 2                    Anguilla          630890         Full Time
# 3        Syrian Arab Republic          116400         Full Time
# 4                    Dominica          523499         Full Time
# ...                       ...             ...               ...
# 299996                   Cuba          949580            Intern
# 299997                Bolivia          802830         Full Time
# 299998         Western Sahara          257240         Full Time
# 299999         United Kingdom          575770            Intern
# 300000               Anguilla          343930         Full Time
#
#        Employee_Rating Employee_Rating_New
# 0                  3.9                 4.8
# 1                  4.3                 5.6
# 2                  3.1                 3.2
# 3                  3.1                 3.2
# 4                  4.8                 6.6
# ...                ...                 ...
# 299996             2.6                 2.2
# 299997             0.6                 1.5
# 299998             2.4                 1.8
# 299999             3.3                 3.6
# 300000             3.3                 3.6
#
# [300001 rows x 9 columns]

# %% [markdown]
# ### 120. Rearrange the columns in the below order. Overwrite to the current DataFrame object.

# %%
new_order = ["Name", "Employee_Job_Title", "Company_Name", 
             "Employee_City", "Employee_Country", "Employment_Status", 
             "Employee_Salary", "Employee_Rating", "Employee_Rating_New"]

df = data[new_order]
df
# Out:
#                   Name                       Employee_Job_Title  \
# 0       Spencer Adkins                          Equities trader
# 1         Julie Morton  Diplomatic Services operational officer
# 2         Matthew Hall               Regulatory affairs officer
# 3           Brad Scott                      Production engineer
# 4        Theresa Owens                      Production engineer
# ...                ...                                      ...
# 299996  Michele Butler                            Administrator
# 299997     Lynn Wilson                            Administrator
# 299998   Lindsey Keith                                     Make
# 299999   Karen Delgado                                  Actuary
# 300000    Chris Anders                      Production engineer
#
#                         Company_Name      Employee_City  \
# 0                     James and Sons     New Russellton
# 1                      Nichols-James  North Melissafurt
# 2                          Scott Inc           Wardfort
# 3       Johnston, Fleming and Tanner     West Jamesview
# 4           Baker, Allen and Edwards          Whiteside
# ...                              ...                ...
# 299996  Johnston, Fleming and Tanner         Aliciafort
# 299997                 Nichols-James   New Cindychester
# 299998                 Nichols-James       Whitakerbury
# 299999                James and Sons     New Russellton
# 300000                     Scott Inc           Wardfort
#
#              Employee_Country Employment_Status Employee_Salary  \
# 0       Palestinian Territory         Full Time          321520
# 1            Marshall Islands         Full Time          589090
# 2                    Anguilla         Full Time          630890
# 3        Syrian Arab Republic         Full Time          116400
# 4                    Dominica         Full Time          523499
# ...                       ...               ...             ...
# 299996                   Cuba            Intern          949580
# 299997                Bolivia         Full Time          802830
# 299998         Western Sahara         Full Time          257240
# 299999         United Kingdom            Intern          575770
# 300000               Anguilla         Full Time          343930
#
#        Employee_Rating Employee_Rating_New
# 0                  3.9                 4.8
# 1                  4.3                 5.6
# 2                  3.1                 3.2
# 3                  3.1                 3.2
# 4                  4.8                 6.6
# ...                ...                 ...
# 299996             2.6                 2.2
# 299997             0.6                 1.5
# 299998             2.4                 1.8
# 299999             3.3                 3.6
# 300000             3.3                 3.6
#
# [300001 rows x 9 columns]

# %% [markdown]
# ### 121. Add a New column of 'First_name' and compute it from the 'Name' column

# %%
df[["First_name", "Last_name"]] = df["Name"].str.split(expand=True)
df
# Out:
# C:\Users\johnw\miniconda3\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                   Name                       Employee_Job_Title  \
# 0       Spencer Adkins                          Equities trader
# 1         Julie Morton  Diplomatic Services operational officer
# 2         Matthew Hall               Regulatory affairs officer
# 3           Brad Scott                      Production engineer
# 4        Theresa Owens                      Production engineer
# ...                ...                                      ...
# 299996  Michele Butler                            Administrator
# 299997     Lynn Wilson                            Administrator
# 299998   Lindsey Keith                                     Make
# 299999   Karen Delgado                                  Actuary
# 300000    Chris Anders                      Production engineer
#
#                         Company_Name      Employee_City  \
# 0                     James and Sons     New Russellton
# 1                      Nichols-James  North Melissafurt
# 2                          Scott Inc           Wardfort
# 3       Johnston, Fleming and Tanner     West Jamesview
# 4           Baker, Allen and Edwards          Whiteside
# ...                              ...                ...
# 299996  Johnston, Fleming and Tanner         Aliciafort
# 299997                 Nichols-James   New Cindychester
# 299998                 Nichols-James       Whitakerbury
# 299999                James and Sons     New Russellton
# 300000                     Scott Inc           Wardfort
#
#              Employee_Country Employment_Status Employee_Salary  \
# 0       Palestinian Territory         Full Time          321520
# 1            Marshall Islands         Full Time          589090
# 2                    Anguilla         Full Time          630890
# 3        Syrian Arab Republic         Full Time          116400
# 4                    Dominica         Full Time          523499
# ...                       ...               ...             ...
# 299996                   Cuba            Intern          949580
# 299997                Bolivia         Full Time          802830
# 299998         Western Sahara         Full Time          257240
# 299999         United Kingdom            Intern          575770
# 300000               Anguilla         Full Time          343930
#
#        Employee_Rating Employee_Rating_New First_name Last_name
# 0                  3.9                 4.8    Spencer    Adkins
# 1                  4.3                 5.6      Julie    Morton
# 2                  3.1                 3.2    Matthew      Hall
# 3                  3.1                 3.2       Brad     Scott
# 4                  4.8                 6.6    Theresa     Owens
# ...                ...                 ...        ...       ...
# 299996             2.6                 2.2    Michele    Butler
# 299997             0.6                 1.5       Lynn    Wilson
# 299998             2.4                 1.8    Lindsey     Keith
# 299999             3.3                 3.6      Karen   Delgado
# 300000             3.3                 3.6      Chris    Anders
#
# [300001 rows x 11 columns]

# %% [markdown]
# ### 122. Add a New column of 'Last_name' and compute it from the 'Name' column

# %%
# See above

# %% [markdown]
# ### 123. Drop the 'Name' column inplace from the DataFrame.

# %%
df = df.drop(columns=["Name"])
df
# Out:
#                              Employee_Job_Title                  Company_Name  \
# 0                               Equities trader                James and Sons
# 1       Diplomatic Services operational officer                 Nichols-James
# 2                    Regulatory affairs officer                     Scott Inc
# 3                           Production engineer  Johnston, Fleming and Tanner
# 4                           Production engineer      Baker, Allen and Edwards
# ...                                         ...                           ...
# 299996                            Administrator  Johnston, Fleming and Tanner
# 299997                            Administrator                 Nichols-James
# 299998                                     Make                 Nichols-James
# 299999                                  Actuary                James and Sons
# 300000                      Production engineer                     Scott Inc
#
#             Employee_City       Employee_Country Employment_Status  \
# 0          New Russellton  Palestinian Territory         Full Time
# 1       North Melissafurt       Marshall Islands         Full Time
# 2                Wardfort               Anguilla         Full Time
# 3          West Jamesview   Syrian Arab Republic         Full Time
# 4               Whiteside               Dominica         Full Time
# ...                   ...                    ...               ...
# 299996         Aliciafort                   Cuba            Intern
# 299997   New Cindychester                Bolivia         Full Time
# 299998       Whitakerbury         Western Sahara         Full Time
# 299999     New Russellton         United Kingdom            Intern
# 300000           Wardfort               Anguilla         Full Time
#
#        Employee_Salary Employee_Rating Employee_Rating_New First_name  \
# 0               321520             3.9                 4.8    Spencer
# 1               589090             4.3                 5.6      Julie
# 2               630890             3.1                 3.2    Matthew
# 3               116400             3.1                 3.2       Brad
# 4               523499             4.8                 6.6    Theresa
# ...                ...             ...                 ...        ...
# 299996          949580             2.6                 2.2    Michele
# 299997          802830             0.6                 1.5       Lynn
# 299998          257240             2.4                 1.8    Lindsey
# 299999          575770             3.3                 3.6      Karen
# 300000          343930             3.3                 3.6      Chris
#
#        Last_name
# 0         Adkins
# 1         Morton
# 2           Hall
# 3          Scott
# 4          Owens
# ...          ...
# 299996    Butler
# 299997    Wilson
# 299998     Keith
# 299999   Delgado
# 300000    Anders
#
# [300001 rows x 10 columns]

# %% [markdown]
# ### 124. Rearrange the columns in the below order. Overwrite to the current DataFrame object.

# %%
new_order = ["First_name", "Last_name", "Employee_Job_Title", "Company_Name", 
             "Employee_City", "Employee_Country", "Employment_Status", 
             "Employee_Salary", "Employee_Rating", "Employee_Rating_New"]

df = df[new_order]
df
# Out:
#        First_name Last_name                       Employee_Job_Title  \
# 0         Spencer    Adkins                          Equities trader
# 1           Julie    Morton  Diplomatic Services operational officer
# 2         Matthew      Hall               Regulatory affairs officer
# 3            Brad     Scott                      Production engineer
# 4         Theresa     Owens                      Production engineer
# ...           ...       ...                                      ...
# 299996    Michele    Butler                            Administrator
# 299997       Lynn    Wilson                            Administrator
# 299998    Lindsey     Keith                                     Make
# 299999      Karen   Delgado                                  Actuary
# 300000      Chris    Anders                      Production engineer
#
#                         Company_Name      Employee_City  \
# 0                     James and Sons     New Russellton
# 1                      Nichols-James  North Melissafurt
# 2                          Scott Inc           Wardfort
# 3       Johnston, Fleming and Tanner     West Jamesview
# 4           Baker, Allen and Edwards          Whiteside
# ...                              ...                ...
# 299996  Johnston, Fleming and Tanner         Aliciafort
# 299997                 Nichols-James   New Cindychester
# 299998                 Nichols-James       Whitakerbury
# 299999                James and Sons     New Russellton
# 300000                     Scott Inc           Wardfort
#
#              Employee_Country Employment_Status Employee_Salary  \
# 0       Palestinian Territory         Full Time          321520
# 1            Marshall Islands         Full Time          589090
# 2                    Anguilla         Full Time          630890
# 3        Syrian Arab Republic         Full Time          116400
# 4                    Dominica         Full Time          523499
# ...                       ...               ...             ...
# 299996                   Cuba            Intern          949580
# 299997                Bolivia         Full Time          802830
# 299998         Western Sahara         Full Time          257240
# 299999         United Kingdom            Intern          575770
# 300000               Anguilla         Full Time          343930
#
#        Employee_Rating Employee_Rating_New
# 0                  3.9                 4.8
# 1                  4.3                 5.6
# 2                  3.1                 3.2
# 3                  3.1                 3.2
# 4                  4.8                 6.6
# ...                ...                 ...
# 299996             2.6                 2.2
# 299997             0.6                 1.5
# 299998             2.4                 1.8
# 299999             3.3                 3.6
# 300000             3.3                 3.6
#
# [300001 rows x 10 columns]

# %% [markdown]
# ### 125. Compute the cosine similarity between the series 'Employee_Rating' and 'Employee_Rating_New'

# %%
from scipy import spatial

# %%
1 - spatial.distance.cosine(df["Employee_Rating"], df["Employee_Rating_New"]) # similarity = 1 - distance
# Out:
# 0.9792427912408228

# %% [markdown]
# ### 126. Rename the columns and store to a new DataFrame 'df_renamed':

# %% [markdown]
# 1. Employee_Rating -> Rating
# 2. Employee_Country -> Country
# 3. Employee_Salary -> Salary
# 4. Employee_Rating_New -> Rating_New
# 5. Employment_Status -> Employment_type
# 6. Employment_City -> City

# %%
df_renamed = df.rename(
    columns={
        "Employee_Rating": "Rating", "Employee_Country": "Country",
        "Employee_Salary": "Salary", "Employee_Rating_New": "Rating_New",
        "Employment_Status": "Employment_type", "Employee_City": "City"
    }
)
df_renamed
# Out:
#        First_name Last_name                       Employee_Job_Title  \
# 0         Spencer    Adkins                          Equities trader
# 1           Julie    Morton  Diplomatic Services operational officer
# 2         Matthew      Hall               Regulatory affairs officer
# 3            Brad     Scott                      Production engineer
# 4         Theresa     Owens                      Production engineer
# ...           ...       ...                                      ...
# 299996    Michele    Butler                            Administrator
# 299997       Lynn    Wilson                            Administrator
# 299998    Lindsey     Keith                                     Make
# 299999      Karen   Delgado                                  Actuary
# 300000      Chris    Anders                      Production engineer
#
#                         Company_Name               City  \
# 0                     James and Sons     New Russellton
# 1                      Nichols-James  North Melissafurt
# 2                          Scott Inc           Wardfort
# 3       Johnston, Fleming and Tanner     West Jamesview
# 4           Baker, Allen and Edwards          Whiteside
# ...                              ...                ...
# 299996  Johnston, Fleming and Tanner         Aliciafort
# 299997                 Nichols-James   New Cindychester
# 299998                 Nichols-James       Whitakerbury
# 299999                James and Sons     New Russellton
# 300000                     Scott Inc           Wardfort
#
#                       Country Employment_type  Salary Rating Rating_New
# 0       Palestinian Territory       Full Time  321520    3.9        4.8
# 1            Marshall Islands       Full Time  589090    4.3        5.6
# 2                    Anguilla       Full Time  630890    3.1        3.2
# 3        Syrian Arab Republic       Full Time  116400    3.1        3.2
# 4                    Dominica       Full Time  523499    4.8        6.6
# ...                       ...             ...     ...    ...        ...
# 299996                   Cuba          Intern  949580    2.6        2.2
# 299997                Bolivia       Full Time  802830    0.6        1.5
# 299998         Western Sahara       Full Time  257240    2.4        1.8
# 299999         United Kingdom          Intern  575770    3.3        3.6
# 300000               Anguilla       Full Time  343930    3.3        3.6
#
# [300001 rows x 10 columns]

# %% [markdown]
# ### 127. Rename the columns (inplace):

# %% [markdown]
# 1. Employee_Rating -> Rating
# 2. Employee_Country -> Country
# 3. Employee_Salary -> Salary
# 4. Employee_Rating_New -> Rating_New
# 5. Employment_Status -> Employment_type
# 6. Employment_City -> City

# %%
df.rename(
    columns={
        "Employee_Rating": "Rating", "Employee_Country": "Country",
        "Employee_Salary": "Salary", "Employee_Rating_New": "Rating_New",
        "Employment_Status": "Employment_type", "Employee_City": "City"
    }, inplace=True
)
df
# Out:
#        First_name Last_name                       Employee_Job_Title  \
# 0         Spencer    Adkins                          Equities trader
# 1           Julie    Morton  Diplomatic Services operational officer
# 2         Matthew      Hall               Regulatory affairs officer
# 3            Brad     Scott                      Production engineer
# 4         Theresa     Owens                      Production engineer
# ...           ...       ...                                      ...
# 299996    Michele    Butler                            Administrator
# 299997       Lynn    Wilson                            Administrator
# 299998    Lindsey     Keith                                     Make
# 299999      Karen   Delgado                                  Actuary
# 300000      Chris    Anders                      Production engineer
#
#                         Company_Name               City  \
# 0                     James and Sons     New Russellton
# 1                      Nichols-James  North Melissafurt
# 2                          Scott Inc           Wardfort
# 3       Johnston, Fleming and Tanner     West Jamesview
# 4           Baker, Allen and Edwards          Whiteside
# ...                              ...                ...
# 299996  Johnston, Fleming and Tanner         Aliciafort
# 299997                 Nichols-James   New Cindychester
# 299998                 Nichols-James       Whitakerbury
# 299999                James and Sons     New Russellton
# 300000                     Scott Inc           Wardfort
#
#                       Country Employment_type  Salary Rating Rating_New
# 0       Palestinian Territory       Full Time  321520    3.9        4.8
# 1            Marshall Islands       Full Time  589090    4.3        5.6
# 2                    Anguilla       Full Time  630890    3.1        3.2
# 3        Syrian Arab Republic       Full Time  116400    3.1        3.2
# 4                    Dominica       Full Time  523499    4.8        6.6
# ...                       ...             ...     ...    ...        ...
# 299996                   Cuba          Intern  949580    2.6        2.2
# 299997                Bolivia       Full Time  802830    0.6        1.5
# 299998         Western Sahara       Full Time  257240    2.4        1.8
# 299999         United Kingdom          Intern  575770    3.3        3.6
# 300000               Anguilla       Full Time  343930    3.3        3.6
#
# [300001 rows x 10 columns]

# %% [markdown]
# ### 128. Count the number of NaN values in each column

# %%
df.isnull().sum()
# Out:
# First_name            0
# Last_name             0
# Employee_Job_Title    0
# Company_Name          0
# City                  0
# Country               0
# Employment_type       0
# Salary                0
# Rating                0
# Rating_New            0
# dtype: int64

# %% [markdown]
# ### 129. Write a function that takes the employee_salary and returns:

# %% [markdown]
# 1. "High" if the salary is >= 600000
# 2. "Medium" if the salary is > 300000 and < 600000
# 3. "Low" otherwise.
#
# Hint: Use the apply() method.
#
# **Store the returned series to a new column 'Salary_category'.**

# %%
def categorize_salary(salary):
    if salary >= 600000:
        return "High"
    elif 300000 < salary < 600000:
        return "Medium"
    else:
        return "Low"

# %%
df["Salary_category"] = df["Salary"].apply(categorize_salary)
df
# Out:
#        First_name Last_name                       Employee_Job_Title  \
# 0         Spencer    Adkins                          Equities trader
# 1           Julie    Morton  Diplomatic Services operational officer
# 2         Matthew      Hall               Regulatory affairs officer
# 3            Brad     Scott                      Production engineer
# 4         Theresa     Owens                      Production engineer
# ...           ...       ...                                      ...
# 299996    Michele    Butler                            Administrator
# 299997       Lynn    Wilson                            Administrator
# 299998    Lindsey     Keith                                     Make
# 299999      Karen   Delgado                                  Actuary
# 300000      Chris    Anders                      Production engineer
#
#                         Company_Name               City  \
# 0                     James and Sons     New Russellton
# 1                      Nichols-James  North Melissafurt
# 2                          Scott Inc           Wardfort
# 3       Johnston, Fleming and Tanner     West Jamesview
# 4           Baker, Allen and Edwards          Whiteside
# ...                              ...                ...
# 299996  Johnston, Fleming and Tanner         Aliciafort
# 299997                 Nichols-James   New Cindychester
# 299998                 Nichols-James       Whitakerbury
# 299999                James and Sons     New Russellton
# 300000                     Scott Inc           Wardfort
#
#                       Country Employment_type  Salary Rating Rating_New  \
# 0       Palestinian Territory       Full Time  321520    3.9        4.8
# 1            Marshall Islands       Full Time  589090    4.3        5.6
# 2                    Anguilla       Full Time  630890    3.1        3.2
# 3        Syrian Arab Republic       Full Time  116400    3.1        3.2
# 4                    Dominica       Full Time  523499    4.8        6.6
# ...                       ...             ...     ...    ...        ...
# 299996                   Cuba          Intern  949580    2.6        2.2
# 299997                Bolivia       Full Time  802830    0.6        1.5
# 299998         Western Sahara       Full Time  257240    2.4        1.8
# 299999         United Kingdom          Intern  575770    3.3        3.6
# 300000               Anguilla       Full Time  343930    3.3        3.6
#
#        Salary_category
# 0               Medium
# 1               Medium
# 2                 High
# 3                  Low
# 4               Medium
# ...                ...
# 299996            High
# 299997            High
# 299998             Low
# 299999          Medium
# 300000          Medium
#
# [300001 rows x 11 columns]

# %% [markdown]
# ### 130. Print the count distribution of the 'Salary_category' column.

# %%
df["Salary_category"].value_counts()
# Out:
# High      120018
# Medium     90152
# Low        89831
# Name: Salary_category, dtype: int64

# %% [markdown]
# ### 131.  Map every Company_Name to a unique integer value. Name the new column "Company_ID".

# %% [markdown]
# For instance, if the data has 5 companies, "Company A" -> 1, "Company B" -> 2, "Company C" -> 3, "Company D" -> 4, "Company E" -> 5.

# %%
dict = {}
for i, name in enumerate(df["Company_Name"].unique().tolist()):
    dict[name] = i

df["Company_ID"] = df["Company_Name"].map(dict)
df
# Out:
#        First_name Last_name                       Employee_Job_Title  \
# 0         Spencer    Adkins                          Equities trader
# 1           Julie    Morton  Diplomatic Services operational officer
# 2         Matthew      Hall               Regulatory affairs officer
# 3            Brad     Scott                      Production engineer
# 4         Theresa     Owens                      Production engineer
# ...           ...       ...                                      ...
# 299996    Michele    Butler                            Administrator
# 299997       Lynn    Wilson                            Administrator
# 299998    Lindsey     Keith                                     Make
# 299999      Karen   Delgado                                  Actuary
# 300000      Chris    Anders                      Production engineer
#
#                         Company_Name               City  \
# 0                     James and Sons     New Russellton
# 1                      Nichols-James  North Melissafurt
# 2                          Scott Inc           Wardfort
# 3       Johnston, Fleming and Tanner     West Jamesview
# 4           Baker, Allen and Edwards          Whiteside
# ...                              ...                ...
# 299996  Johnston, Fleming and Tanner         Aliciafort
# 299997                 Nichols-James   New Cindychester
# 299998                 Nichols-James       Whitakerbury
# 299999                James and Sons     New Russellton
# 300000                     Scott Inc           Wardfort
#
#                       Country Employment_type  Salary Rating Rating_New  \
# 0       Palestinian Territory       Full Time  321520    3.9        4.8
# 1            Marshall Islands       Full Time  589090    4.3        5.6
# 2                    Anguilla       Full Time  630890    3.1        3.2
# 3        Syrian Arab Republic       Full Time  116400    3.1        3.2
# 4                    Dominica       Full Time  523499    4.8        6.6
# ...                       ...             ...     ...    ...        ...
# 299996                   Cuba          Intern  949580    2.6        2.2
# 299997                Bolivia       Full Time  802830    0.6        1.5
# 299998         Western Sahara       Full Time  257240    2.4        1.8
# 299999         United Kingdom          Intern  575770    3.3        3.6
# 300000               Anguilla       Full Time  343930    3.3        3.6
#
#        Salary_category  Company_ID
# 0               Medium           0
# 1               Medium           1
# 2                 High           2
# 3                  Low           3
# 4               Medium           4
# ...                ...         ...
# 299996            High           3
# 299997            High           1
# 299998             Low           1
# 299999          Medium           0
# 300000          Medium           2
#
# [300001 rows x 12 columns]

# %% [markdown]
# ### 132. Generate one-hot lables for the 'Employment_type' column. You don't have to add this as a column to the DataFrame.

# %%
pd.get_dummies(df["Employment_type"], prefix="Employment_type")
# Out:
#         Employment_type_Full Time  Employment_type_Intern
# 0                               1                       0
# 1                               1                       0
# 2                               1                       0
# 3                               1                       0
# 4                               1                       0
# ...                           ...                     ...
# 299996                          0                       1
# 299997                          1                       0
# 299998                          1                       0
# 299999                          0                       1
# 300000                          1                       0
#
# [300001 rows x 2 columns]

# %% [markdown]
# ### 133. Print the number of rows where 'City' belongs to the following list of cities.

# %% [markdown]
# Use the isin() method.

# %%
city_filter_list = ["New Russellton", "Whiteside", "Kristaburgh"]

row_count = df["City"].isin(city_filter_list).sum()

print(row_count)
# Out:
# 90054

# %% [markdown]
# ### 134. Print the name of the person with the 10th largest salary.

# %%
data.sort_values("Employee_Salary", ascending=False).iloc[9, 0]
# Out:
# 'Elizabeth Bell'

# %% [markdown]
# ### 135. Print the name of the person with the 10th largest salary. If there are multiple people with the same salary, print all names.

# %%
tenth_salary = data.sort_values("Employee_Salary", ascending=False).iloc[9, 5]

data.query(f"Employee_Salary == {tenth_salary}").Name.values
# Out:
# array(['Allen Chavez', 'David Ryan', 'Elizabeth Bell', 'Megan Petersen'],
#       dtype=object)

# %% [markdown]
# ### 136. Print a cross tabulation of Company Name and Employment Type.

# %%
pd.crosstab(df["Company_Name"], df["Employment_type"])
# Out:
# Employment_type                 Full Time  Intern
# Company_Name
# Andrade LLC                         15964    4019
# Baker, Allen and Edwards            16118    3966
# Bullock-Carrillo                    16135    3928
# Campos, Reynolds and Mccormick      15930    3997
# James and Sons                      15888    3980
# Johnston, Fleming and Tanner        15832    3979
# Marshall-Holloway                   15871    3988
# Matthews Inc                        16082    4001
# Nelson-Li                           16027    4105
# Nichols-James                       15872    4039
# Scott Inc                           16397    3994
# Taylor-Ramos                        16086    4036
# Thomas-Spencer                      16037    4105
# Wallace, Smith and Shepard          15467    3897
# White, Mcclain and Cobb             16305    3956

# %% [markdown]
# ### 137. Print the standard deviation of the Salary column.

# %%
df["Salary"].std()
# Out:
# 288361.9787166691

# %% [markdown]
# ### 138. Iterates over the DataFrame's first five rows and print the Company Name

# %% [markdown]
# Note: You have to write a for loop here explicitly and iterate.

# %%
for i in range(5):
    print(df.iloc[i, 3])
# Out:
# James and Sons
# Nichols-James
# Scott Inc
# Johnston, Fleming and Tanner
# Baker, Allen and Edwards

# %% [markdown]
# ### 139. Select the last row corresponding to every City in the dataframe

# %%
df.drop_duplicates(subset="City", keep="last")
# Out:
#        First_name  Last_name                       Employee_Job_Title  \
# 299959  Elizabeth    Perkins        Sales promotion account executive
# 299960  Alexander    Kaufman  Diplomatic Services operational officer
# 299969   Jennifer    Navarro             Investment banker, corporate
# 299991    William  Rodriguez                               Ergonomist
# 299995      Nancy       Neal                              Optometrist
# 299996    Michele     Butler                            Administrator
# 299997       Lynn     Wilson                            Administrator
# 299998    Lindsey      Keith                                     Make
# 299999      Karen    Delgado                                  Actuary
# 300000      Chris     Anders                      Production engineer
#
#                         Company_Name               City         Country  \
# 299959             Marshall-Holloway     West Jamesview       Sri Lanka
# 299960  Johnston, Fleming and Tanner       Ricardomouth           Congo
# 299969  Johnston, Fleming and Tanner        Kristaburgh           Nauru
# 299991                     Scott Inc          Whiteside     New Zealand
# 299995              Bullock-Carrillo  North Melissafurt           Samoa
# 299996  Johnston, Fleming and Tanner         Aliciafort            Cuba
# 299997                 Nichols-James   New Cindychester         Bolivia
# 299998                 Nichols-James       Whitakerbury  Western Sahara
# 299999                James and Sons     New Russellton  United Kingdom
# 300000                     Scott Inc           Wardfort        Anguilla
#
#        Employment_type  Salary Rating Rating_New Salary_category  Company_ID
# 299959       Full Time  723780    3.4        3.8            High          12
# 299960       Full Time  729070    1.0        1.5            High           3
# 299969       Full Time  472090    4.3        5.6          Medium           3
# 299991       Full Time  214400    1.5        1.5             Low           2
# 299995          Intern   99670    3.3        3.6             Low          11
# 299996          Intern  949580    2.6        2.2            High           3
# 299997       Full Time  802830    0.6        1.5            High           1
# 299998       Full Time  257240    2.4        1.8             Low           1
# 299999          Intern  575770    3.3        3.6          Medium           0
# 300000       Full Time  343930    3.3        3.6          Medium           2

# %% [markdown]
# ### 140. Sort the dataframe on Employee salary column (inplace).

# %%
df.sort_values("Salary", inplace=True)
df
# Out:
#        First_name  Last_name  \
# 205070   Courtney  Singleton
# 54531     Kristen    Vasquez
# 229395      Grace      Smith
# 185700    Vanessa         Wu
# 226792      Penny       Meza
# ...           ...        ...
# 23536      Dennis     Sexton
# 50461       Logan    Jackson
# 153993      Jason    Jenkins
# 51642     Richard    Kennedy
# 70356        Anna     Lawson
#
#                                        Employee_Job_Title  \
# 205070                       Garment/textile technologist
# 54531   Armed forces logistics/support/administrative ...
# 229395                          Trading standards officer
# 185700                                    Patent examiner
# 226792                          Trading standards officer
# ...                                                   ...
# 23536             Diplomatic Services operational officer
# 50461                                          Ergonomist
# 153993                  Sales promotion account executive
# 51642                                      Energy manager
# 70356                                 Production engineer
#
#                           Company_Name               City  \
# 205070         White, Mcclain and Cobb   New Cindychester
# 54531          White, Mcclain and Cobb           Wardfort
# 229395    Johnston, Fleming and Tanner     West Jamesview
# 185700  Campos, Reynolds and Mccormick  North Melissafurt
# 226792      Wallace, Smith and Shepard           Wardfort
# ...                                ...                ...
# 23536   Campos, Reynolds and Mccormick        Kristaburgh
# 50461          White, Mcclain and Cobb           Wardfort
# 153993                    Taylor-Ramos         Aliciafort
# 51642                   Thomas-Spencer         Aliciafort
# 70356                     Taylor-Ramos        Kristaburgh
#
#                        Country Employment_type  Salary Rating Rating_New  \
# 205070                Ethiopia       Full Time       0    2.8        2.6
# 54531                  Bermuda       Full Time       0    3.4        3.8
# 229395  Libyan Arab Jamahiriya          Intern      10    1.1        1.5
# 185700                  Zambia       Full Time      10    1.3        1.5
# 226792                 Albania       Full Time      10    0.7        1.5
# ...                        ...             ...     ...    ...        ...
# 23536           United Kingdom       Full Time  999970    0.9        1.5
# 50461             Saint Helena       Full Time  999980    2.0        1.5
# 153993                Pakistan       Full Time  999980    2.6        2.2
# 51642             Cook Islands       Full Time  999980    2.4        1.8
# 70356                  Lesotho       Full Time  999990    4.0        5.0
#
#        Salary_category  Company_ID
# 205070             Low           9
# 54531              Low           9
# 229395             Low           3
# 185700             Low           8
# 226792             Low          13
# ...                ...         ...
# 23536             High           8
# 50461             High           9
# 153993            High           7
# 51642             High          10
# 70356             High           7
#
# [300001 rows x 12 columns]

# %% [markdown]
# ### 141. The task above has distorted the indexing. Reset the index inplace and drop the current index.

# %%
df = df.reset_index(drop=True)
df
# Out:
#        First_name  Last_name  \
# 0        Courtney  Singleton
# 1         Kristen    Vasquez
# 2           Grace      Smith
# 3         Vanessa         Wu
# 4           Penny       Meza
# ...           ...        ...
# 299996     Dennis     Sexton
# 299997      Logan    Jackson
# 299998      Jason    Jenkins
# 299999    Richard    Kennedy
# 300000       Anna     Lawson
#
#                                        Employee_Job_Title  \
# 0                            Garment/textile technologist
# 1       Armed forces logistics/support/administrative ...
# 2                               Trading standards officer
# 3                                         Patent examiner
# 4                               Trading standards officer
# ...                                                   ...
# 299996            Diplomatic Services operational officer
# 299997                                         Ergonomist
# 299998                  Sales promotion account executive
# 299999                                     Energy manager
# 300000                                Production engineer
#
#                           Company_Name               City  \
# 0              White, Mcclain and Cobb   New Cindychester
# 1              White, Mcclain and Cobb           Wardfort
# 2         Johnston, Fleming and Tanner     West Jamesview
# 3       Campos, Reynolds and Mccormick  North Melissafurt
# 4           Wallace, Smith and Shepard           Wardfort
# ...                                ...                ...
# 299996  Campos, Reynolds and Mccormick        Kristaburgh
# 299997         White, Mcclain and Cobb           Wardfort
# 299998                    Taylor-Ramos         Aliciafort
# 299999                  Thomas-Spencer         Aliciafort
# 300000                    Taylor-Ramos        Kristaburgh
#
#                        Country Employment_type  Salary Rating Rating_New  \
# 0                     Ethiopia       Full Time       0    2.8        2.6
# 1                      Bermuda       Full Time       0    3.4        3.8
# 2       Libyan Arab Jamahiriya          Intern      10    1.1        1.5
# 3                       Zambia       Full Time      10    1.3        1.5
# 4                      Albania       Full Time      10    0.7        1.5
# ...                        ...             ...     ...    ...        ...
# 299996          United Kingdom       Full Time  999970    0.9        1.5
# 299997            Saint Helena       Full Time  999980    2.0        1.5
# 299998                Pakistan       Full Time  999980    2.6        2.2
# 299999            Cook Islands       Full Time  999980    2.4        1.8
# 300000                 Lesotho       Full Time  999990    4.0        5.0
#
#        Salary_category  Company_ID
# 0                  Low           9
# 1                  Low           9
# 2                  Low           3
# 3                  Low           8
# 4                  Low          13
# ...                ...         ...
# 299996            High           8
# 299997            High           9
# 299998            High           7
# 299999            High          10
# 300000            High           7
#
# [300001 rows x 12 columns]

# %% [markdown]
# ### 142. Now check whether the Salary column is monotonically increasing or not.

# %%
df["Salary"].is_monotonic
# Out:
# True

# %% [markdown]
# ### 143-145. Print the 25th, 50th and 75th percentile of the Salary column

# %%
df["Salary"].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25    250000.0
# 0.50    500780.0
# 0.75    749710.0
# Name: Salary, dtype: object

# %% [markdown]
# ### 146. Plot a scatter plot between the Salary column and Rating.

# %%
data.iloc[0:100, :].plot.scatter(x="Employee_Salary", y="Employee_Rating");

# %% [markdown]
# ### 147. Distribute the Salary column in 10 equal sized bins.

# %%
df["Salary_Bin"] = pd.cut(df["Salary"], 10, include_lowest=True)
df
# Out:
#        First_name  Last_name  \
# 0        Courtney  Singleton
# 1         Kristen    Vasquez
# 2           Grace      Smith
# 3         Vanessa         Wu
# 4           Penny       Meza
# ...           ...        ...
# 299996     Dennis     Sexton
# 299997      Logan    Jackson
# 299998      Jason    Jenkins
# 299999    Richard    Kennedy
# 300000       Anna     Lawson
#
#                                        Employee_Job_Title  \
# 0                            Garment/textile technologist
# 1       Armed forces logistics/support/administrative ...
# 2                               Trading standards officer
# 3                                         Patent examiner
# 4                               Trading standards officer
# ...                                                   ...
# 299996            Diplomatic Services operational officer
# 299997                                         Ergonomist
# 299998                  Sales promotion account executive
# 299999                                     Energy manager
# 300000                                Production engineer
#
#                           Company_Name               City  \
# 0              White, Mcclain and Cobb   New Cindychester
# 1              White, Mcclain and Cobb           Wardfort
# 2         Johnston, Fleming and Tanner     West Jamesview
# 3       Campos, Reynolds and Mccormick  North Melissafurt
# 4           Wallace, Smith and Shepard           Wardfort
# ...                                ...                ...
# 299996  Campos, Reynolds and Mccormick        Kristaburgh
# 299997         White, Mcclain and Cobb           Wardfort
# 299998                    Taylor-Ramos         Aliciafort
# 299999                  Thomas-Spencer         Aliciafort
# 300000                    Taylor-Ramos        Kristaburgh
#
#                        Country Employment_type  Salary Rating Rating_New  \
# 0                     Ethiopia       Full Time       0    2.8        2.6
# 1                      Bermuda       Full Time       0    3.4        3.8
# 2       Libyan Arab Jamahiriya          Intern      10    1.1        1.5
# 3                       Zambia       Full Time      10    1.3        1.5
# 4                      Albania       Full Time      10    0.7        1.5
# ...                        ...             ...     ...    ...        ...
# 299996          United Kingdom       Full Time  999970    0.9        1.5
# 299997            Saint Helena       Full Time  999980    2.0        1.5
# 299998                Pakistan       Full Time  999980    2.6        2.2
# 299999            Cook Islands       Full Time  999980    2.4        1.8
# 300000                 Lesotho       Full Time  999990    4.0        5.0
#
#        Salary_category  Company_ID            Salary_Bin
# 0                  Low           9   (-999.991, 99999.0]
# 1                  Low           9   (-999.991, 99999.0]
# 2                  Low           3   (-999.991, 99999.0]
# 3                  Low           8   (-999.991, 99999.0]
# 4                  Low          13   (-999.991, 99999.0]
# ...                ...         ...                   ...
# 299996            High           8  (899991.0, 999990.0]
# 299997            High           9  (899991.0, 999990.0]
# 299998            High           7  (899991.0, 999990.0]
# 299999            High          10  (899991.0, 999990.0]
# 300000            High           7  (899991.0, 999990.0]
#
# [300001 rows x 13 columns]

# %% [markdown]
# ### 148. Convert the Salary column to numpy array

# %%
np.array(df["Salary"])
# Out:
# array([0, 0, 10, ..., 999980, 999980, 999990], dtype=object)

# %% [markdown]
# ### 149. Convert the Rating column to numpy array

# %%
np.array(df["Rating"])
# Out:
# array([2.8, 3.4, 1.1, ..., 2.6, 2.4, 4.0], dtype=object)

# %% [markdown]
# ### 150. Compute the cosine similarity between the numpy arrays created in 148 and 149.

# %%
1 - spatial.distance.cosine(np.array(df["Salary"]), np.array(df["Rating"]))
# Out:
# 0.7504054171312089

# %% [markdown]
# Great job solving this notebook. Go to Pandas Notebook 4: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-after-employee-f84e02a1-fb6a-428e-af90-8dd99855749a/%2Fnotebook.ipynb)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=adc5a3ee-5f61-4725-8e46-ccb07899acfc' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
