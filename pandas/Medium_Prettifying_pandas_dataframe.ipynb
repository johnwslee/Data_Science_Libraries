# %% [markdown]
# # 0. Data 📦

# %%
import numpy as np
import pandas as pd
pd.options.display.precision = 2
from seaborn import load_dataset
# Load sample data
columns = {'bill_length_mm': 'length', 
           'bill_depth_mm': 'depth',
           'flipper_length_mm': 'flipper',
           'body_mass_g': 'mass'}
df = load_dataset('penguins').rename(columns=columns)
df.head()
# Out:
#   species     island  length  depth  flipper    mass     sex
# 0  Adelie  Torgersen    39.1   18.7    181.0  3750.0    Male
# 1  Adelie  Torgersen    39.5   17.4    186.0  3800.0  Female
# 2  Adelie  Torgersen    40.3   18.0    195.0  3250.0  Female
# 3  Adelie  Torgersen     NaN    NaN      NaN     NaN     NaN
# 4  Adelie  Torgersen    36.7   19.3    193.0  3450.0  Female

# %% [markdown]
# # 1. Prettifying DataFrames ✨

# %% [markdown]
# In order to style DataFrames, we need to access the `.style` attribute which returns a Styler object:

# %%
type(df.style)
# Out:
# pandas.io.formats.style.Styler

# %% [markdown]
# This Styler object creates an HTML table which can be further styled using CSS.

# %% [markdown]
# ## 1.1. Gradients 🌈

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
#          length  depth  flipper  mass
# length     1.00  -0.24     0.66  0.60
# depth     -0.24   1.00    -0.58 -0.47
# flipper    0.66  -0.58     1.00  0.87
# mass       0.60  -0.47     0.87  1.00

# %%
(correlation_matrix
 .style
 .background_gradient(cmap='seismic_r', axis=None))
# Out:
# <style type="text/css">
# #T_c0c90_row0_col0, #T_c0c90_row1_col1, #T_c0c90_row2_col2, #T_c0c90_row3_col3 {
#   background-color: #00004c;
#   color: #f1f1f1;
# }
# #T_c0c90_row0_col1, #T_c0c90_row1_col0 {
#   background-color: #f00000;
#   color: #f1f1f1;
# }
# #T_c0c90_row0_col2, #T_c0c90_row2_col0 {
#   background-color: #0000e6;
#   color: #f1f1f1;
# }
# #T_c0c90_row0_col3, #T_c0c90_row3_col0 {
#   background-color: #0505ff;
#   color: #f1f1f1;
# }
# #T_c0c90_row1_col2, #T_c0c90_row2_col1 {
#   background-color: #800000;
#   color: #f1f1f1;
# }
# #T_c0c90_row1_col3, #T_c0c90_row3_col1 {
#   background-color: #a30000;
#   color: #f1f1f1;
# }
# #T_c0c90_row2_col3, #T_c0c90_row3_col2 {
#   background-color: #000084;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c0c90">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0c90_level0_col0" class="col_heading level0 col0" >length</th>
#       <th id="T_c0c90_level0_col1" class="col_heading level0 col1" >depth</th>
#       <th id="T_c0c90_level0_col2" class="col_heading level0 col2" >flipper</th>
#       <th id="T_c0c90_level0_col3" class="col_heading level0 col3" >mass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0c90_level0_row0" class="row_heading level0 row0" >length</th>
#       <td id="T_c0c90_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c0c90_row0_col1" class="data row0 col1" >-0.235053</td>
#       <td id="T_c0c90_row0_col2" class="data row0 col2" >0.656181</td>
#       <td id="T_c0c90_row0_col3" class="data row0 col3" >0.595110</td>
#     </tr>
#     <tr>
#       <th id="T_c0c90_level0_row1" class="row_heading level0 row1" >depth</th>
#       <td id="T_c0c90_row1_col0" class="data row1 col0" >-0.235053</td>
#       <td id="T_c0c90_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_c0c90_row1_col2" class="data row1 col2" >-0.583851</td>
#       <td id="T_c0c90_row1_col3" class="data row1 col3" >-0.471916</td>
#     </tr>
#     <tr>
#       <th id="T_c0c90_level0_row2" class="row_heading level0 row2" >flipper</th>
#       <td id="T_c0c90_row2_col0" class="data row2 col0" >0.656181</td>
#       <td id="T_c0c90_row2_col1" class="data row2 col1" >-0.583851</td>
#       <td id="T_c0c90_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_c0c90_row2_col3" class="data row2 col3" >0.871202</td>
#     </tr>
#     <tr>
#       <th id="T_c0c90_level0_row3" class="row_heading level0 row3" >mass</th>
#       <td id="T_c0c90_row3_col0" class="data row3 col0" >0.595110</td>
#       <td id="T_c0c90_row3_col1" class="data row3 col1" >-0.471916</td>
#       <td id="T_c0c90_row3_col2" class="data row3 col2" >0.871202</td>
#       <td id="T_c0c90_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# By passing `axis=None`, the colour gradients are applied along the entire table rather than within a specific axis.

# %% [markdown]
# The name of the desired colour palette is passed onto the `cmap` parameter. For this parameter, we can use any [Matplotlib colourmap](https://matplotlib.org/stable/tutorials/colors/colormaps.html).

# %% [markdown]
# Here’s a useful tip for colourmaps: If you ever need to flip the colour scale, adding `_r` suffix to the colour map name will do the trick. For instance, if we used `'seismic'` instead of `'seismic_r'`, negative correlations would have been blue and positive correlations would have been red.

# %% [markdown]
# The previous example doesn’t look identical to the example shown at the beginning of this post. It needs a few more customisations to look the same:

# %%
(correlation_matrix
 .style
 .background_gradient(cmap='seismic_r', axis=None)
 .set_properties(**{'text-align': 'center', 'padding': '12px'})
 .set_caption('CORRELATION MATRIX'))
# Out:
# <style type="text/css">
# #T_633b6_row0_col0, #T_633b6_row1_col1, #T_633b6_row2_col2, #T_633b6_row3_col3 {
#   background-color: #00004c;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_633b6_row0_col1, #T_633b6_row1_col0 {
#   background-color: #f00000;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_633b6_row0_col2, #T_633b6_row2_col0 {
#   background-color: #0000e6;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_633b6_row0_col3, #T_633b6_row3_col0 {
#   background-color: #0505ff;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_633b6_row1_col2, #T_633b6_row2_col1 {
#   background-color: #800000;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_633b6_row1_col3, #T_633b6_row3_col1 {
#   background-color: #a30000;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# #T_633b6_row2_col3, #T_633b6_row3_col2 {
#   background-color: #000084;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
# }
# </style>
# <table id="T_633b6">
#   <caption>CORRELATION MATRIX</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_633b6_level0_col0" class="col_heading level0 col0" >length</th>
#       <th id="T_633b6_level0_col1" class="col_heading level0 col1" >depth</th>
#       <th id="T_633b6_level0_col2" class="col_heading level0 col2" >flipper</th>
#       <th id="T_633b6_level0_col3" class="col_heading level0 col3" >mass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_633b6_level0_row0" class="row_heading level0 row0" >length</th>
#       <td id="T_633b6_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_633b6_row0_col1" class="data row0 col1" >-0.235053</td>
#       <td id="T_633b6_row0_col2" class="data row0 col2" >0.656181</td>
#       <td id="T_633b6_row0_col3" class="data row0 col3" >0.595110</td>
#     </tr>
#     <tr>
#       <th id="T_633b6_level0_row1" class="row_heading level0 row1" >depth</th>
#       <td id="T_633b6_row1_col0" class="data row1 col0" >-0.235053</td>
#       <td id="T_633b6_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_633b6_row1_col2" class="data row1 col2" >-0.583851</td>
#       <td id="T_633b6_row1_col3" class="data row1 col3" >-0.471916</td>
#     </tr>
#     <tr>
#       <th id="T_633b6_level0_row2" class="row_heading level0 row2" >flipper</th>
#       <td id="T_633b6_row2_col0" class="data row2 col0" >0.656181</td>
#       <td id="T_633b6_row2_col1" class="data row2 col1" >-0.583851</td>
#       <td id="T_633b6_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_633b6_row2_col3" class="data row2 col3" >0.871202</td>
#     </tr>
#     <tr>
#       <th id="T_633b6_level0_row3" class="row_heading level0 row3" >mass</th>
#       <td id="T_633b6_row3_col0" class="data row3 col0" >0.595110</td>
#       <td id="T_633b6_row3_col1" class="data row3 col1" >-0.471916</td>
#       <td id="T_633b6_row3_col2" class="data row3 col2" >0.871202</td>
#       <td id="T_633b6_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We center-aligned the values (`{'text-align': 'center'}`) and increased the row height (`{'padding': '12px'}`) with `.set_properties()`. Then, we added a caption above the table with `.set_caption()`. In this example, we have applied colour gradients to the background. We can also apply colour gradients to the text with `.text_gradient()`:

# %%
(correlation_matrix
 .style
 .text_gradient(cmap='seismic_r', axis=None))
# Out:
# <style type="text/css">
# #T_143a1_row0_col0, #T_143a1_row1_col1, #T_143a1_row2_col2, #T_143a1_row3_col3 {
#   color: #00004c;
# }
# #T_143a1_row0_col1, #T_143a1_row1_col0 {
#   color: #f00000;
# }
# #T_143a1_row0_col2, #T_143a1_row2_col0 {
#   color: #0000e6;
# }
# #T_143a1_row0_col3, #T_143a1_row3_col0 {
#   color: #0505ff;
# }
# #T_143a1_row1_col2, #T_143a1_row2_col1 {
#   color: #800000;
# }
# #T_143a1_row1_col3, #T_143a1_row3_col1 {
#   color: #a30000;
# }
# #T_143a1_row2_col3, #T_143a1_row3_col2 {
#   color: #000084;
# }
# </style>
# <table id="T_143a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_143a1_level0_col0" class="col_heading level0 col0" >length</th>
#       <th id="T_143a1_level0_col1" class="col_heading level0 col1" >depth</th>
#       <th id="T_143a1_level0_col2" class="col_heading level0 col2" >flipper</th>
#       <th id="T_143a1_level0_col3" class="col_heading level0 col3" >mass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_143a1_level0_row0" class="row_heading level0 row0" >length</th>
#       <td id="T_143a1_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_143a1_row0_col1" class="data row0 col1" >-0.235053</td>
#       <td id="T_143a1_row0_col2" class="data row0 col2" >0.656181</td>
#       <td id="T_143a1_row0_col3" class="data row0 col3" >0.595110</td>
#     </tr>
#     <tr>
#       <th id="T_143a1_level0_row1" class="row_heading level0 row1" >depth</th>
#       <td id="T_143a1_row1_col0" class="data row1 col0" >-0.235053</td>
#       <td id="T_143a1_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_143a1_row1_col2" class="data row1 col2" >-0.583851</td>
#       <td id="T_143a1_row1_col3" class="data row1 col3" >-0.471916</td>
#     </tr>
#     <tr>
#       <th id="T_143a1_level0_row2" class="row_heading level0 row2" >flipper</th>
#       <td id="T_143a1_row2_col0" class="data row2 col0" >0.656181</td>
#       <td id="T_143a1_row2_col1" class="data row2 col1" >-0.583851</td>
#       <td id="T_143a1_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_143a1_row2_col3" class="data row2 col3" >0.871202</td>
#     </tr>
#     <tr>
#       <th id="T_143a1_level0_row3" class="row_heading level0 row3" >mass</th>
#       <td id="T_143a1_row3_col0" class="data row3 col0" >0.595110</td>
#       <td id="T_143a1_row3_col1" class="data row3 col1" >-0.471916</td>
#       <td id="T_143a1_row3_col2" class="data row3 col2" >0.871202</td>
#       <td id="T_143a1_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# If useful, we can chain both types of gradients as well:

# %%
(correlation_matrix
 .style
 .background_gradient(cmap='YlGn', axis=None)
 .text_gradient(cmap='YlGn_r', axis=None))
# Out:
# <style type="text/css">
# #T_aa5bc_row0_col0, #T_aa5bc_row1_col1, #T_aa5bc_row2_col2, #T_aa5bc_row3_col3 {
#   background-color: #004529;
#   color: #f1f1f1;
#   color: #ffffe5;
# }
# #T_aa5bc_row0_col1, #T_aa5bc_row1_col0 {
#   background-color: #e0f3a8;
#   color: #000000;
#   color: #1a7d40;
# }
# #T_aa5bc_row0_col2, #T_aa5bc_row2_col0 {
#   background-color: #197c40;
#   color: #f1f1f1;
#   color: #e1f3a9;
# }
# #T_aa5bc_row0_col3, #T_aa5bc_row3_col0 {
#   background-color: #248644;
#   color: #f1f1f1;
#   color: #d7efa2;
# }
# #T_aa5bc_row1_col2, #T_aa5bc_row2_col1 {
#   background-color: #ffffe5;
#   color: #000000;
#   color: #004529;
# }
# #T_aa5bc_row1_col3, #T_aa5bc_row3_col1 {
#   background-color: #fafdcc;
#   color: #000000;
#   color: #005931;
# }
# #T_aa5bc_row2_col3, #T_aa5bc_row3_col2 {
#   background-color: #005b32;
#   color: #f1f1f1;
#   color: #fafdc9;
# }
# </style>
# <table id="T_aa5bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa5bc_level0_col0" class="col_heading level0 col0" >length</th>
#       <th id="T_aa5bc_level0_col1" class="col_heading level0 col1" >depth</th>
#       <th id="T_aa5bc_level0_col2" class="col_heading level0 col2" >flipper</th>
#       <th id="T_aa5bc_level0_col3" class="col_heading level0 col3" >mass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa5bc_level0_row0" class="row_heading level0 row0" >length</th>
#       <td id="T_aa5bc_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_aa5bc_row0_col1" class="data row0 col1" >-0.235053</td>
#       <td id="T_aa5bc_row0_col2" class="data row0 col2" >0.656181</td>
#       <td id="T_aa5bc_row0_col3" class="data row0 col3" >0.595110</td>
#     </tr>
#     <tr>
#       <th id="T_aa5bc_level0_row1" class="row_heading level0 row1" >depth</th>
#       <td id="T_aa5bc_row1_col0" class="data row1 col0" >-0.235053</td>
#       <td id="T_aa5bc_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_aa5bc_row1_col2" class="data row1 col2" >-0.583851</td>
#       <td id="T_aa5bc_row1_col3" class="data row1 col3" >-0.471916</td>
#     </tr>
#     <tr>
#       <th id="T_aa5bc_level0_row2" class="row_heading level0 row2" >flipper</th>
#       <td id="T_aa5bc_row2_col0" class="data row2 col0" >0.656181</td>
#       <td id="T_aa5bc_row2_col1" class="data row2 col1" >-0.583851</td>
#       <td id="T_aa5bc_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_aa5bc_row2_col3" class="data row2 col3" >0.871202</td>
#     </tr>
#     <tr>
#       <th id="T_aa5bc_level0_row3" class="row_heading level0 row3" >mass</th>
#       <td id="T_aa5bc_row3_col0" class="data row3 col0" >0.595110</td>
#       <td id="T_aa5bc_row3_col1" class="data row3 col1" >-0.471916</td>
#       <td id="T_aa5bc_row3_col2" class="data row3 col2" >0.871202</td>
#       <td id="T_aa5bc_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Before we wrap up this section, I want to show one more useful example. Let’s imagine we had a simple confusion matrix:

# %%
# Create made-up predictions
df['predicted'] = df['species']
df.loc[140:160, 'predicted'] = 'Gentoo'
df.loc[210:250, 'predicted'] = 'Adelie'
# Create confusion matrix
confusion_matrix = pd.crosstab(df['species'], df['predicted'])
confusion_matrix
# Out:
# predicted  Adelie  Chinstrap  Gentoo
# species
# Adelie        140          0      12
# Chinstrap      10         49       9
# Gentoo         31          0      93

# %% [markdown]
# We can do a bit of make-over to make it more useful and pretty:

# %%
(confusion_matrix
 .style
 .background_gradient('Greys')
 .set_caption('CONFUSION MATRIX')
 .set_properties(
     **{'text-align': 'center',
        'padding': '12px',
        'width': '80px'}
 )
 .set_table_styles(
     [{'selector': 'th.col_heading', 
       'props': 'text-align: center'},
      {'selector': 'caption', 
       'props': [
           ('text-align', 'center'), 
           ('font-size', '11pt'), 
           ('font-weight', 'bold')
       ]}
     ]
 )
)
# Out:
# <style type="text/css">
# #T_b66db th.col_heading {
#   text-align: center;
# }
# #T_b66db caption {
#   text-align: center;
#   font-size: 11pt;
#   font-weight: bold;
# }
# #T_b66db_row0_col0, #T_b66db_row1_col1, #T_b66db_row2_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
#   width: 80px;
# }
# #T_b66db_row0_col1, #T_b66db_row1_col0, #T_b66db_row1_col2, #T_b66db_row2_col1 {
#   background-color: #ffffff;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 80px;
# }
# #T_b66db_row0_col2 {
#   background-color: #fbfbfb;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 80px;
# }
# #T_b66db_row2_col0 {
#   background-color: #e9e9e9;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 80px;
# }
# </style>
# <table id="T_b66db">
#   <caption>CONFUSION MATRIX</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >predicted</th>
#       <th id="T_b66db_level0_col0" class="col_heading level0 col0" >Adelie</th>
#       <th id="T_b66db_level0_col1" class="col_heading level0 col1" >Chinstrap</th>
#       <th id="T_b66db_level0_col2" class="col_heading level0 col2" >Gentoo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >species</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b66db_level0_row0" class="row_heading level0 row0" >Adelie</th>
#       <td id="T_b66db_row0_col0" class="data row0 col0" >140</td>
#       <td id="T_b66db_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_b66db_row0_col2" class="data row0 col2" >12</td>
#     </tr>
#     <tr>
#       <th id="T_b66db_level0_row1" class="row_heading level0 row1" >Chinstrap</th>
#       <td id="T_b66db_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_b66db_row1_col1" class="data row1 col1" >49</td>
#       <td id="T_b66db_row1_col2" class="data row1 col2" >9</td>
#     </tr>
#     <tr>
#       <th id="T_b66db_level0_row2" class="row_heading level0 row2" >Gentoo</th>
#       <td id="T_b66db_row2_col0" class="data row2 col0" >31</td>
#       <td id="T_b66db_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_b66db_row2_col2" class="data row2 col2" >93</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Since we familiarised with the first 5 lines of the code in the previous examples, let’s understand what the remaining code is doing:
#
# - `.set_properties(**{'width': '80px'})`: to increase column width
#
# - `.set_table_styles([{'selector': 'th.col_heading', 'props': 'text-align: center'}])`: to align column headers in center
#
# - `.set_table_styles([{'selector': 'caption', 'props': [('text-align', 'center' ), ('font-size', '11pt'), ('font-weight', 'bold')]}])`: to center-align caption, increase its font size and bold it.

# %% [markdown]
# ## 1.2. Colour bars 📊

# %% [markdown]
# Now, let’s see how to add data bars to the DataFrame. We will first create a pivot table, then use `.bar()` to create data bars:

# %%
# Create a pivot table with missing data
pivot = df.pivot_table('mass', ['species', 'island'], 'sex')
pivot.iloc[-2, 0] = np.nan
# Style
pivot.style.bar(color='aquamarine')
# Out:
# <style type="text/css">
# #T_5c62d_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, aquamarine 72.0%, transparent 72.0%);
# }
# #T_5c62d_row0_col1, #T_5c62d_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, aquamarine 73.8%, transparent 73.8%);
# }
# #T_5c62d_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, aquamarine 71.5%, transparent 71.5%);
# }
# #T_5c62d_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, aquamarine 72.6%, transparent 72.6%);
# }
# #T_5c62d_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, aquamarine 73.6%, transparent 73.6%);
# }
# #T_5c62d_row3_col0 {
#   width: 10em;
# }
# #T_5c62d_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, aquamarine 71.8%, transparent 71.8%);
# }
# #T_5c62d_row4_col0, #T_5c62d_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, aquamarine 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_5c62d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >sex</th>
#       <th id="T_5c62d_level0_col0" class="col_heading level0 col0" >Female</th>
#       <th id="T_5c62d_level0_col1" class="col_heading level0 col1" >Male</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >species</th>
#       <th class="index_name level1" >island</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c62d_level0_row0" class="row_heading level0 row0" rowspan="3">Adelie</th>
#       <th id="T_5c62d_level1_row0" class="row_heading level1 row0" >Biscoe</th>
#       <td id="T_5c62d_row0_col0" class="data row0 col0" >3369.318182</td>
#       <td id="T_5c62d_row0_col1" class="data row0 col1" >4050.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5c62d_level1_row1" class="row_heading level1 row1" >Dream</th>
#       <td id="T_5c62d_row1_col0" class="data row1 col0" >3344.444444</td>
#       <td id="T_5c62d_row1_col1" class="data row1 col1" >4045.535714</td>
#     </tr>
#     <tr>
#       <th id="T_5c62d_level1_row2" class="row_heading level1 row2" >Torgersen</th>
#       <td id="T_5c62d_row2_col0" class="data row2 col0" >3395.833333</td>
#       <td id="T_5c62d_row2_col1" class="data row2 col1" >4034.782609</td>
#     </tr>
#     <tr>
#       <th id="T_5c62d_level0_row3" class="row_heading level0 row3" >Chinstrap</th>
#       <th id="T_5c62d_level1_row3" class="row_heading level1 row3" >Dream</th>
#       <td id="T_5c62d_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_5c62d_row3_col1" class="data row3 col1" >3938.970588</td>
#     </tr>
#     <tr>
#       <th id="T_5c62d_level0_row4" class="row_heading level0 row4" >Gentoo</th>
#       <th id="T_5c62d_level1_row4" class="row_heading level1 row4" >Biscoe</th>
#       <td id="T_5c62d_row4_col0" class="data row4 col0" >4679.741379</td>
#       <td id="T_5c62d_row4_col1" class="data row4 col1" >5484.836066</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# This can be styled further just like in the previous examples:

# %%
(pivot
 .style
 .bar(color='aquamarine')
 .set_properties(padding='8px', width='50'))
# Out:
# <style type="text/css">
# #T_132e7_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, aquamarine 72.0%, transparent 72.0%);
#   padding: 8px;
#   width: 50;
# }
# #T_132e7_row0_col1, #T_132e7_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, aquamarine 73.8%, transparent 73.8%);
#   padding: 8px;
#   width: 50;
# }
# #T_132e7_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, aquamarine 71.5%, transparent 71.5%);
#   padding: 8px;
#   width: 50;
# }
# #T_132e7_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, aquamarine 72.6%, transparent 72.6%);
#   padding: 8px;
#   width: 50;
# }
# #T_132e7_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, aquamarine 73.6%, transparent 73.6%);
#   padding: 8px;
#   width: 50;
# }
# #T_132e7_row3_col0 {
#   width: 10em;
#   padding: 8px;
#   width: 50;
# }
# #T_132e7_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, aquamarine 71.8%, transparent 71.8%);
#   padding: 8px;
#   width: 50;
# }
# #T_132e7_row4_col0, #T_132e7_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, aquamarine 100.0%, transparent 100.0%);
#   padding: 8px;
#   width: 50;
# }
# </style>
# <table id="T_132e7">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >sex</th>
#       <th id="T_132e7_level0_col0" class="col_heading level0 col0" >Female</th>
#       <th id="T_132e7_level0_col1" class="col_heading level0 col1" >Male</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >species</th>
#       <th class="index_name level1" >island</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_132e7_level0_row0" class="row_heading level0 row0" rowspan="3">Adelie</th>
#       <th id="T_132e7_level1_row0" class="row_heading level1 row0" >Biscoe</th>
#       <td id="T_132e7_row0_col0" class="data row0 col0" >3369.318182</td>
#       <td id="T_132e7_row0_col1" class="data row0 col1" >4050.000000</td>
#     </tr>
#     <tr>
#       <th id="T_132e7_level1_row1" class="row_heading level1 row1" >Dream</th>
#       <td id="T_132e7_row1_col0" class="data row1 col0" >3344.444444</td>
#       <td id="T_132e7_row1_col1" class="data row1 col1" >4045.535714</td>
#     </tr>
#     <tr>
#       <th id="T_132e7_level1_row2" class="row_heading level1 row2" >Torgersen</th>
#       <td id="T_132e7_row2_col0" class="data row2 col0" >3395.833333</td>
#       <td id="T_132e7_row2_col1" class="data row2 col1" >4034.782609</td>
#     </tr>
#     <tr>
#       <th id="T_132e7_level0_row3" class="row_heading level0 row3" >Chinstrap</th>
#       <th id="T_132e7_level1_row3" class="row_heading level1 row3" >Dream</th>
#       <td id="T_132e7_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_132e7_row3_col1" class="data row3 col1" >3938.970588</td>
#     </tr>
#     <tr>
#       <th id="T_132e7_level0_row4" class="row_heading level0 row4" >Gentoo</th>
#       <th id="T_132e7_level1_row4" class="row_heading level1 row4" >Biscoe</th>
#       <td id="T_132e7_row4_col0" class="data row4 col0" >4679.741379</td>
#       <td id="T_132e7_row4_col1" class="data row4 col1" >5484.836066</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Previously we got familiar with this format: `.set_properties(**{'padding': '8px', 'width': '50'})`. The code above shows an alternative way to pass your arguments to `.set_properties()`.

# %% [markdown]
# If you have positive and negative values, you can format the data as follows by passing two colours (`color=['salmon', 'lightgreen']`) and aligning the bars in the middle (`align='mid'`):

# %%
# Style on toy data
(pd.DataFrame({'feature': ['a', 'b', 'c', 'd', 'e', 'f'],
               'coefficient': [30, 10, 1, -5, -10, -20]})
 .style
 .bar(color=['salmon', 'lightgreen'], align='mid')
 .set_properties(**{'text-align': 'center'})
 .set_table_styles([{'selector': 'th.col_heading', 
                     'props': 'text-align: center'}]))
# Out:
# <style type="text/css">
# #T_2f62b th.col_heading {
#   text-align: center;
# }
# #T_2f62b_row0_col0, #T_2f62b_row1_col0, #T_2f62b_row2_col0, #T_2f62b_row3_col0, #T_2f62b_row4_col0, #T_2f62b_row5_col0 {
#   text-align: center;
# }
# #T_2f62b_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, lightgreen 40.0%, lightgreen 100.0%, transparent 100.0%);
#   text-align: center;
# }
# #T_2f62b_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, lightgreen 40.0%, lightgreen 60.0%, transparent 60.0%);
#   text-align: center;
# }
# #T_2f62b_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, lightgreen 40.0%, lightgreen 42.0%, transparent 42.0%);
#   text-align: center;
# }
# #T_2f62b_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 30.0%, salmon 30.0%, salmon 40.0%, transparent 40.0%);
#   text-align: center;
# }
# #T_2f62b_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.0%, salmon 20.0%, salmon 40.0%, transparent 40.0%);
#   text-align: center;
# }
# #T_2f62b_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 40.0%, transparent 40.0%);
#   text-align: center;
# }
# </style>
# <table id="T_2f62b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f62b_level0_col0" class="col_heading level0 col0" >feature</th>
#       <th id="T_2f62b_level0_col1" class="col_heading level0 col1" >coefficient</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f62b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f62b_row0_col0" class="data row0 col0" >a</td>
#       <td id="T_2f62b_row0_col1" class="data row0 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_2f62b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2f62b_row1_col0" class="data row1 col0" >b</td>
#       <td id="T_2f62b_row1_col1" class="data row1 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2f62b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2f62b_row2_col0" class="data row2 col0" >c</td>
#       <td id="T_2f62b_row2_col1" class="data row2 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2f62b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2f62b_row3_col0" class="data row3 col0" >d</td>
#       <td id="T_2f62b_row3_col1" class="data row3 col1" >-5</td>
#     </tr>
#     <tr>
#       <th id="T_2f62b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2f62b_row4_col0" class="data row4 col0" >e</td>
#       <td id="T_2f62b_row4_col1" class="data row4 col1" >-10</td>
#     </tr>
#     <tr>
#       <th id="T_2f62b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2f62b_row5_col0" class="data row5 col0" >f</td>
#       <td id="T_2f62b_row5_col1" class="data row5 col1" >-20</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 1.3. Highlights 🔆

# %% [markdown]
# Firstly, we can highlight minimum values from each column like this:

# %%
pivot.style.highlight_min(color='pink')
# Out:
# <style type="text/css">
# #T_a05e5_row1_col0, #T_a05e5_row3_col1 {
#   background-color: pink;
# }
# </style>
# <table id="T_a05e5">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >sex</th>
#       <th id="T_a05e5_level0_col0" class="col_heading level0 col0" >Female</th>
#       <th id="T_a05e5_level0_col1" class="col_heading level0 col1" >Male</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >species</th>
#       <th class="index_name level1" >island</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a05e5_level0_row0" class="row_heading level0 row0" rowspan="3">Adelie</th>
#       <th id="T_a05e5_level1_row0" class="row_heading level1 row0" >Biscoe</th>
#       <td id="T_a05e5_row0_col0" class="data row0 col0" >3369.318182</td>
#       <td id="T_a05e5_row0_col1" class="data row0 col1" >4050.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a05e5_level1_row1" class="row_heading level1 row1" >Dream</th>
#       <td id="T_a05e5_row1_col0" class="data row1 col0" >3344.444444</td>
#       <td id="T_a05e5_row1_col1" class="data row1 col1" >4045.535714</td>
#     </tr>
#     <tr>
#       <th id="T_a05e5_level1_row2" class="row_heading level1 row2" >Torgersen</th>
#       <td id="T_a05e5_row2_col0" class="data row2 col0" >3395.833333</td>
#       <td id="T_a05e5_row2_col1" class="data row2 col1" >4034.782609</td>
#     </tr>
#     <tr>
#       <th id="T_a05e5_level0_row3" class="row_heading level0 row3" >Chinstrap</th>
#       <th id="T_a05e5_level1_row3" class="row_heading level1 row3" >Dream</th>
#       <td id="T_a05e5_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_a05e5_row3_col1" class="data row3 col1" >3938.970588</td>
#     </tr>
#     <tr>
#       <th id="T_a05e5_level0_row4" class="row_heading level0 row4" >Gentoo</th>
#       <th id="T_a05e5_level1_row4" class="row_heading level1 row4" >Biscoe</th>
#       <td id="T_a05e5_row4_col0" class="data row4 col0" >4679.741379</td>
#       <td id="T_a05e5_row4_col1" class="data row4 col1" >5484.836066</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There’s an equivalent function for maximum values:

# %%
pivot.style.highlight_max(color='lightgreen')
# Out:
# <style type="text/css">
# #T_22961_row4_col0, #T_22961_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_22961">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >sex</th>
#       <th id="T_22961_level0_col0" class="col_heading level0 col0" >Female</th>
#       <th id="T_22961_level0_col1" class="col_heading level0 col1" >Male</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >species</th>
#       <th class="index_name level1" >island</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22961_level0_row0" class="row_heading level0 row0" rowspan="3">Adelie</th>
#       <th id="T_22961_level1_row0" class="row_heading level1 row0" >Biscoe</th>
#       <td id="T_22961_row0_col0" class="data row0 col0" >3369.318182</td>
#       <td id="T_22961_row0_col1" class="data row0 col1" >4050.000000</td>
#     </tr>
#     <tr>
#       <th id="T_22961_level1_row1" class="row_heading level1 row1" >Dream</th>
#       <td id="T_22961_row1_col0" class="data row1 col0" >3344.444444</td>
#       <td id="T_22961_row1_col1" class="data row1 col1" >4045.535714</td>
#     </tr>
#     <tr>
#       <th id="T_22961_level1_row2" class="row_heading level1 row2" >Torgersen</th>
#       <td id="T_22961_row2_col0" class="data row2 col0" >3395.833333</td>
#       <td id="T_22961_row2_col1" class="data row2 col1" >4034.782609</td>
#     </tr>
#     <tr>
#       <th id="T_22961_level0_row3" class="row_heading level0 row3" >Chinstrap</th>
#       <th id="T_22961_level1_row3" class="row_heading level1 row3" >Dream</th>
#       <td id="T_22961_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_22961_row3_col1" class="data row3 col1" >3938.970588</td>
#     </tr>
#     <tr>
#       <th id="T_22961_level0_row4" class="row_heading level0 row4" >Gentoo</th>
#       <th id="T_22961_level1_row4" class="row_heading level1 row4" >Biscoe</th>
#       <td id="T_22961_row4_col0" class="data row4 col0" >4679.741379</td>
#       <td id="T_22961_row4_col1" class="data row4 col1" >5484.836066</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can chain these highlight functions together like this:

# %%
(pivot
 .style
 .highlight_min(color='pink')
 .highlight_max(color='lightgreen'))
# Out:
# <style type="text/css">
# #T_127ee_row1_col0, #T_127ee_row3_col1 {
#   background-color: pink;
# }
# #T_127ee_row4_col0, #T_127ee_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_127ee">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >sex</th>
#       <th id="T_127ee_level0_col0" class="col_heading level0 col0" >Female</th>
#       <th id="T_127ee_level0_col1" class="col_heading level0 col1" >Male</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >species</th>
#       <th class="index_name level1" >island</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_127ee_level0_row0" class="row_heading level0 row0" rowspan="3">Adelie</th>
#       <th id="T_127ee_level1_row0" class="row_heading level1 row0" >Biscoe</th>
#       <td id="T_127ee_row0_col0" class="data row0 col0" >3369.318182</td>
#       <td id="T_127ee_row0_col1" class="data row0 col1" >4050.000000</td>
#     </tr>
#     <tr>
#       <th id="T_127ee_level1_row1" class="row_heading level1 row1" >Dream</th>
#       <td id="T_127ee_row1_col0" class="data row1 col0" >3344.444444</td>
#       <td id="T_127ee_row1_col1" class="data row1 col1" >4045.535714</td>
#     </tr>
#     <tr>
#       <th id="T_127ee_level1_row2" class="row_heading level1 row2" >Torgersen</th>
#       <td id="T_127ee_row2_col0" class="data row2 col0" >3395.833333</td>
#       <td id="T_127ee_row2_col1" class="data row2 col1" >4034.782609</td>
#     </tr>
#     <tr>
#       <th id="T_127ee_level0_row3" class="row_heading level0 row3" >Chinstrap</th>
#       <th id="T_127ee_level1_row3" class="row_heading level1 row3" >Dream</th>
#       <td id="T_127ee_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_127ee_row3_col1" class="data row3 col1" >3938.970588</td>
#     </tr>
#     <tr>
#       <th id="T_127ee_level0_row4" class="row_heading level0 row4" >Gentoo</th>
#       <th id="T_127ee_level1_row4" class="row_heading level1 row4" >Biscoe</th>
#       <td id="T_127ee_row4_col0" class="data row4 col0" >4679.741379</td>
#       <td id="T_127ee_row4_col1" class="data row4 col1" >5484.836066</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There is also a function for highlighting missing values. Let’s add it to the previous code snippet:

# %%
(pivot
 .style
 .highlight_min(color='pink')
 .highlight_max(color='lightgreen')
 .highlight_null(null_color='grey'))
# Out:
# <style type="text/css">
# #T_1709e_row1_col0, #T_1709e_row3_col1 {
#   background-color: pink;
# }
# #T_1709e_row3_col0 {
#   background-color: grey;
# }
# #T_1709e_row4_col0, #T_1709e_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1709e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >sex</th>
#       <th id="T_1709e_level0_col0" class="col_heading level0 col0" >Female</th>
#       <th id="T_1709e_level0_col1" class="col_heading level0 col1" >Male</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >species</th>
#       <th class="index_name level1" >island</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1709e_level0_row0" class="row_heading level0 row0" rowspan="3">Adelie</th>
#       <th id="T_1709e_level1_row0" class="row_heading level1 row0" >Biscoe</th>
#       <td id="T_1709e_row0_col0" class="data row0 col0" >3369.318182</td>
#       <td id="T_1709e_row0_col1" class="data row0 col1" >4050.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1709e_level1_row1" class="row_heading level1 row1" >Dream</th>
#       <td id="T_1709e_row1_col0" class="data row1 col0" >3344.444444</td>
#       <td id="T_1709e_row1_col1" class="data row1 col1" >4045.535714</td>
#     </tr>
#     <tr>
#       <th id="T_1709e_level1_row2" class="row_heading level1 row2" >Torgersen</th>
#       <td id="T_1709e_row2_col0" class="data row2 col0" >3395.833333</td>
#       <td id="T_1709e_row2_col1" class="data row2 col1" >4034.782609</td>
#     </tr>
#     <tr>
#       <th id="T_1709e_level0_row3" class="row_heading level0 row3" >Chinstrap</th>
#       <th id="T_1709e_level1_row3" class="row_heading level1 row3" >Dream</th>
#       <td id="T_1709e_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_1709e_row3_col1" class="data row3 col1" >3938.970588</td>
#     </tr>
#     <tr>
#       <th id="T_1709e_level0_row4" class="row_heading level0 row4" >Gentoo</th>
#       <th id="T_1709e_level1_row4" class="row_heading level1 row4" >Biscoe</th>
#       <td id="T_1709e_row4_col0" class="data row4 col0" >4679.741379</td>
#       <td id="T_1709e_row4_col1" class="data row4 col1" >5484.836066</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can highlight values between a range like below:

# %%
pivot.style.highlight_between(left=3500, right=4500, color='gold')
# Out:
# <style type="text/css">
# #T_ee5b4_row0_col1, #T_ee5b4_row1_col1, #T_ee5b4_row2_col1, #T_ee5b4_row3_col1 {
#   background-color: gold;
# }
# </style>
# <table id="T_ee5b4">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >sex</th>
#       <th id="T_ee5b4_level0_col0" class="col_heading level0 col0" >Female</th>
#       <th id="T_ee5b4_level0_col1" class="col_heading level0 col1" >Male</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >species</th>
#       <th class="index_name level1" >island</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee5b4_level0_row0" class="row_heading level0 row0" rowspan="3">Adelie</th>
#       <th id="T_ee5b4_level1_row0" class="row_heading level1 row0" >Biscoe</th>
#       <td id="T_ee5b4_row0_col0" class="data row0 col0" >3369.318182</td>
#       <td id="T_ee5b4_row0_col1" class="data row0 col1" >4050.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ee5b4_level1_row1" class="row_heading level1 row1" >Dream</th>
#       <td id="T_ee5b4_row1_col0" class="data row1 col0" >3344.444444</td>
#       <td id="T_ee5b4_row1_col1" class="data row1 col1" >4045.535714</td>
#     </tr>
#     <tr>
#       <th id="T_ee5b4_level1_row2" class="row_heading level1 row2" >Torgersen</th>
#       <td id="T_ee5b4_row2_col0" class="data row2 col0" >3395.833333</td>
#       <td id="T_ee5b4_row2_col1" class="data row2 col1" >4034.782609</td>
#     </tr>
#     <tr>
#       <th id="T_ee5b4_level0_row3" class="row_heading level0 row3" >Chinstrap</th>
#       <th id="T_ee5b4_level1_row3" class="row_heading level1 row3" >Dream</th>
#       <td id="T_ee5b4_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_ee5b4_row3_col1" class="data row3 col1" >3938.970588</td>
#     </tr>
#     <tr>
#       <th id="T_ee5b4_level0_row4" class="row_heading level0 row4" >Gentoo</th>
#       <th id="T_ee5b4_level1_row4" class="row_heading level1 row4" >Biscoe</th>
#       <td id="T_ee5b4_row4_col0" class="data row4 col0" >4679.741379</td>
#       <td id="T_ee5b4_row4_col1" class="data row4 col1" >5484.836066</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can also highlight quantiles:

# %%
pivot.style.highlight_quantile(
    q_left=0.7, axis=None, color='#4ADBC8'
)
# Out:
# <style type="text/css">
# #T_96ccf_row0_col1, #T_96ccf_row4_col0, #T_96ccf_row4_col1 {
#   background-color: #4ADBC8;
# }
# </style>
# <table id="T_96ccf">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >sex</th>
#       <th id="T_96ccf_level0_col0" class="col_heading level0 col0" >Female</th>
#       <th id="T_96ccf_level0_col1" class="col_heading level0 col1" >Male</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >species</th>
#       <th class="index_name level1" >island</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96ccf_level0_row0" class="row_heading level0 row0" rowspan="3">Adelie</th>
#       <th id="T_96ccf_level1_row0" class="row_heading level1 row0" >Biscoe</th>
#       <td id="T_96ccf_row0_col0" class="data row0 col0" >3369.318182</td>
#       <td id="T_96ccf_row0_col1" class="data row0 col1" >4050.000000</td>
#     </tr>
#     <tr>
#       <th id="T_96ccf_level1_row1" class="row_heading level1 row1" >Dream</th>
#       <td id="T_96ccf_row1_col0" class="data row1 col0" >3344.444444</td>
#       <td id="T_96ccf_row1_col1" class="data row1 col1" >4045.535714</td>
#     </tr>
#     <tr>
#       <th id="T_96ccf_level1_row2" class="row_heading level1 row2" >Torgersen</th>
#       <td id="T_96ccf_row2_col0" class="data row2 col0" >3395.833333</td>
#       <td id="T_96ccf_row2_col1" class="data row2 col1" >4034.782609</td>
#     </tr>
#     <tr>
#       <th id="T_96ccf_level0_row3" class="row_heading level0 row3" >Chinstrap</th>
#       <th id="T_96ccf_level1_row3" class="row_heading level1 row3" >Dream</th>
#       <td id="T_96ccf_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_96ccf_row3_col1" class="data row3 col1" >3938.970588</td>
#     </tr>
#     <tr>
#       <th id="T_96ccf_level0_row4" class="row_heading level0 row4" >Gentoo</th>
#       <th id="T_96ccf_level1_row4" class="row_heading level1 row4" >Biscoe</th>
#       <td id="T_96ccf_row4_col0" class="data row4 col0" >4679.741379</td>
#       <td id="T_96ccf_row4_col1" class="data row4 col1" >5484.836066</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Here, we’ve highlighted the top 30%.

# %% [markdown]
# We have used a few different colours so far. If you are wondering what other colour names you could use, check out [this resource](https://matplotlib.org/stable/gallery/color/named_colors.html) for colour names. As shown in the example above, you can also use hexadecimal colours which will give you access to a wider range of options (over 16 million colours!). [Here](https://coolors.co/)’s my favourite resource to explore hexadecimal colour code.

# %% [markdown]
# ## 1.4. Custom colour-code 🎨

# %% [markdown]
# In this last section, we will look at a few other ways to colour-code DataFrames using custom functions. We will use the following two methods to apply our custom styling functions:
#
# - `.applymap()`: elementwise
# - `.apply()`: column/row/tablewise

# %% [markdown]
# ### Elementwise application: `.applymap()`

# %% [markdown]
# Let’s create a small numerical data by slicing the top 8 rows from the numerical columns. We will use a lambda function to colour values above 190 as blue and the rest as grey:

# %%
df_num = df.select_dtypes('number').head(8)
(df_num
 .style
 .applymap(lambda x: f"color: {'blue' if x>190 else 'grey'}"))
# Out:
# <style type="text/css">
# #T_d3d49_row0_col0, #T_d3d49_row0_col1, #T_d3d49_row0_col2, #T_d3d49_row1_col0, #T_d3d49_row1_col1, #T_d3d49_row1_col2, #T_d3d49_row2_col0, #T_d3d49_row2_col1, #T_d3d49_row3_col0, #T_d3d49_row3_col1, #T_d3d49_row3_col2, #T_d3d49_row3_col3, #T_d3d49_row4_col0, #T_d3d49_row4_col1, #T_d3d49_row5_col0, #T_d3d49_row5_col1, #T_d3d49_row5_col2, #T_d3d49_row6_col0, #T_d3d49_row6_col1, #T_d3d49_row6_col2, #T_d3d49_row7_col0, #T_d3d49_row7_col1 {
#   color: grey;
# }
# #T_d3d49_row0_col3, #T_d3d49_row1_col3, #T_d3d49_row2_col2, #T_d3d49_row2_col3, #T_d3d49_row4_col2, #T_d3d49_row4_col3, #T_d3d49_row5_col3, #T_d3d49_row6_col3, #T_d3d49_row7_col2, #T_d3d49_row7_col3 {
#   color: blue;
# }
# </style>
# <table id="T_d3d49">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3d49_level0_col0" class="col_heading level0 col0" >length</th>
#       <th id="T_d3d49_level0_col1" class="col_heading level0 col1" >depth</th>
#       <th id="T_d3d49_level0_col2" class="col_heading level0 col2" >flipper</th>
#       <th id="T_d3d49_level0_col3" class="col_heading level0 col3" >mass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3d49_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d3d49_row0_col0" class="data row0 col0" >39.100000</td>
#       <td id="T_d3d49_row0_col1" class="data row0 col1" >18.700000</td>
#       <td id="T_d3d49_row0_col2" class="data row0 col2" >181.000000</td>
#       <td id="T_d3d49_row0_col3" class="data row0 col3" >3750.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d3d49_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d3d49_row1_col0" class="data row1 col0" >39.500000</td>
#       <td id="T_d3d49_row1_col1" class="data row1 col1" >17.400000</td>
#       <td id="T_d3d49_row1_col2" class="data row1 col2" >186.000000</td>
#       <td id="T_d3d49_row1_col3" class="data row1 col3" >3800.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d3d49_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d3d49_row2_col0" class="data row2 col0" >40.300000</td>
#       <td id="T_d3d49_row2_col1" class="data row2 col1" >18.000000</td>
#       <td id="T_d3d49_row2_col2" class="data row2 col2" >195.000000</td>
#       <td id="T_d3d49_row2_col3" class="data row2 col3" >3250.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d3d49_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d3d49_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_d3d49_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_d3d49_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_d3d49_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d3d49_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d3d49_row4_col0" class="data row4 col0" >36.700000</td>
#       <td id="T_d3d49_row4_col1" class="data row4 col1" >19.300000</td>
#       <td id="T_d3d49_row4_col2" class="data row4 col2" >193.000000</td>
#       <td id="T_d3d49_row4_col3" class="data row4 col3" >3450.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d3d49_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d3d49_row5_col0" class="data row5 col0" >39.300000</td>
#       <td id="T_d3d49_row5_col1" class="data row5 col1" >20.600000</td>
#       <td id="T_d3d49_row5_col2" class="data row5 col2" >190.000000</td>
#       <td id="T_d3d49_row5_col3" class="data row5 col3" >3650.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d3d49_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d3d49_row6_col0" class="data row6 col0" >38.900000</td>
#       <td id="T_d3d49_row6_col1" class="data row6 col1" >17.800000</td>
#       <td id="T_d3d49_row6_col2" class="data row6 col2" >181.000000</td>
#       <td id="T_d3d49_row6_col3" class="data row6 col3" >3625.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d3d49_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d3d49_row7_col0" class="data row7 col0" >39.200000</td>
#       <td id="T_d3d49_row7_col1" class="data row7 col1" >19.600000</td>
#       <td id="T_d3d49_row7_col2" class="data row7 col2" >195.000000</td>
#       <td id="T_d3d49_row7_col3" class="data row7 col3" >4675.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
green = 'background-color: lightgreen'
pink = 'background-color: pink; color: white'
(df_num
 .style
 .applymap(lambda value: green if value>190 else pink))
# Out:
# <style type="text/css">
# #T_0456b_row0_col0, #T_0456b_row0_col1, #T_0456b_row0_col2, #T_0456b_row1_col0, #T_0456b_row1_col1, #T_0456b_row1_col2, #T_0456b_row2_col0, #T_0456b_row2_col1, #T_0456b_row3_col0, #T_0456b_row3_col1, #T_0456b_row3_col2, #T_0456b_row3_col3, #T_0456b_row4_col0, #T_0456b_row4_col1, #T_0456b_row5_col0, #T_0456b_row5_col1, #T_0456b_row5_col2, #T_0456b_row6_col0, #T_0456b_row6_col1, #T_0456b_row6_col2, #T_0456b_row7_col0, #T_0456b_row7_col1 {
#   background-color: pink;
#   color: white;
# }
# #T_0456b_row0_col3, #T_0456b_row1_col3, #T_0456b_row2_col2, #T_0456b_row2_col3, #T_0456b_row4_col2, #T_0456b_row4_col3, #T_0456b_row5_col3, #T_0456b_row6_col3, #T_0456b_row7_col2, #T_0456b_row7_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0456b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0456b_level0_col0" class="col_heading level0 col0" >length</th>
#       <th id="T_0456b_level0_col1" class="col_heading level0 col1" >depth</th>
#       <th id="T_0456b_level0_col2" class="col_heading level0 col2" >flipper</th>
#       <th id="T_0456b_level0_col3" class="col_heading level0 col3" >mass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0456b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0456b_row0_col0" class="data row0 col0" >39.100000</td>
#       <td id="T_0456b_row0_col1" class="data row0 col1" >18.700000</td>
#       <td id="T_0456b_row0_col2" class="data row0 col2" >181.000000</td>
#       <td id="T_0456b_row0_col3" class="data row0 col3" >3750.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0456b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0456b_row1_col0" class="data row1 col0" >39.500000</td>
#       <td id="T_0456b_row1_col1" class="data row1 col1" >17.400000</td>
#       <td id="T_0456b_row1_col2" class="data row1 col2" >186.000000</td>
#       <td id="T_0456b_row1_col3" class="data row1 col3" >3800.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0456b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0456b_row2_col0" class="data row2 col0" >40.300000</td>
#       <td id="T_0456b_row2_col1" class="data row2 col1" >18.000000</td>
#       <td id="T_0456b_row2_col2" class="data row2 col2" >195.000000</td>
#       <td id="T_0456b_row2_col3" class="data row2 col3" >3250.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0456b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0456b_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_0456b_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_0456b_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_0456b_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0456b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0456b_row4_col0" class="data row4 col0" >36.700000</td>
#       <td id="T_0456b_row4_col1" class="data row4 col1" >19.300000</td>
#       <td id="T_0456b_row4_col2" class="data row4 col2" >193.000000</td>
#       <td id="T_0456b_row4_col3" class="data row4 col3" >3450.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0456b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0456b_row5_col0" class="data row5 col0" >39.300000</td>
#       <td id="T_0456b_row5_col1" class="data row5 col1" >20.600000</td>
#       <td id="T_0456b_row5_col2" class="data row5 col2" >190.000000</td>
#       <td id="T_0456b_row5_col3" class="data row5 col3" >3650.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0456b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0456b_row6_col0" class="data row6 col0" >38.900000</td>
#       <td id="T_0456b_row6_col1" class="data row6 col1" >17.800000</td>
#       <td id="T_0456b_row6_col2" class="data row6 col2" >181.000000</td>
#       <td id="T_0456b_row6_col3" class="data row6 col3" >3625.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0456b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0456b_row7_col0" class="data row7 col0" >39.200000</td>
#       <td id="T_0456b_row7_col1" class="data row7 col1" >19.600000</td>
#       <td id="T_0456b_row7_col2" class="data row7 col2" >195.000000</td>
#       <td id="T_0456b_row7_col3" class="data row7 col3" >4675.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can convert the lambda function into a regular function and pass it to `.applymap()`:

# %%
def highlight_190(value):
    green = 'background-color: lightgreen'
    pink = 'background-color: pink; color: white'
    return green if value > 190 else pink

df_num.style.applymap(highlight_190)
# Out:
# <style type="text/css">
# #T_90fe4_row0_col0, #T_90fe4_row0_col1, #T_90fe4_row0_col2, #T_90fe4_row1_col0, #T_90fe4_row1_col1, #T_90fe4_row1_col2, #T_90fe4_row2_col0, #T_90fe4_row2_col1, #T_90fe4_row3_col0, #T_90fe4_row3_col1, #T_90fe4_row3_col2, #T_90fe4_row3_col3, #T_90fe4_row4_col0, #T_90fe4_row4_col1, #T_90fe4_row5_col0, #T_90fe4_row5_col1, #T_90fe4_row5_col2, #T_90fe4_row6_col0, #T_90fe4_row6_col1, #T_90fe4_row6_col2, #T_90fe4_row7_col0, #T_90fe4_row7_col1 {
#   background-color: pink;
#   color: white;
# }
# #T_90fe4_row0_col3, #T_90fe4_row1_col3, #T_90fe4_row2_col2, #T_90fe4_row2_col3, #T_90fe4_row4_col2, #T_90fe4_row4_col3, #T_90fe4_row5_col3, #T_90fe4_row6_col3, #T_90fe4_row7_col2, #T_90fe4_row7_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_90fe4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90fe4_level0_col0" class="col_heading level0 col0" >length</th>
#       <th id="T_90fe4_level0_col1" class="col_heading level0 col1" >depth</th>
#       <th id="T_90fe4_level0_col2" class="col_heading level0 col2" >flipper</th>
#       <th id="T_90fe4_level0_col3" class="col_heading level0 col3" >mass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90fe4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90fe4_row0_col0" class="data row0 col0" >39.100000</td>
#       <td id="T_90fe4_row0_col1" class="data row0 col1" >18.700000</td>
#       <td id="T_90fe4_row0_col2" class="data row0 col2" >181.000000</td>
#       <td id="T_90fe4_row0_col3" class="data row0 col3" >3750.000000</td>
#     </tr>
#     <tr>
#       <th id="T_90fe4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_90fe4_row1_col0" class="data row1 col0" >39.500000</td>
#       <td id="T_90fe4_row1_col1" class="data row1 col1" >17.400000</td>
#       <td id="T_90fe4_row1_col2" class="data row1 col2" >186.000000</td>
#       <td id="T_90fe4_row1_col3" class="data row1 col3" >3800.000000</td>
#     </tr>
#     <tr>
#       <th id="T_90fe4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_90fe4_row2_col0" class="data row2 col0" >40.300000</td>
#       <td id="T_90fe4_row2_col1" class="data row2 col1" >18.000000</td>
#       <td id="T_90fe4_row2_col2" class="data row2 col2" >195.000000</td>
#       <td id="T_90fe4_row2_col3" class="data row2 col3" >3250.000000</td>
#     </tr>
#     <tr>
#       <th id="T_90fe4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_90fe4_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_90fe4_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_90fe4_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_90fe4_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_90fe4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_90fe4_row4_col0" class="data row4 col0" >36.700000</td>
#       <td id="T_90fe4_row4_col1" class="data row4 col1" >19.300000</td>
#       <td id="T_90fe4_row4_col2" class="data row4 col2" >193.000000</td>
#       <td id="T_90fe4_row4_col3" class="data row4 col3" >3450.000000</td>
#     </tr>
#     <tr>
#       <th id="T_90fe4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_90fe4_row5_col0" class="data row5 col0" >39.300000</td>
#       <td id="T_90fe4_row5_col1" class="data row5 col1" >20.600000</td>
#       <td id="T_90fe4_row5_col2" class="data row5 col2" >190.000000</td>
#       <td id="T_90fe4_row5_col3" class="data row5 col3" >3650.000000</td>
#     </tr>
#     <tr>
#       <th id="T_90fe4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_90fe4_row6_col0" class="data row6 col0" >38.900000</td>
#       <td id="T_90fe4_row6_col1" class="data row6 col1" >17.800000</td>
#       <td id="T_90fe4_row6_col2" class="data row6 col2" >181.000000</td>
#       <td id="T_90fe4_row6_col3" class="data row6 col3" >3625.000000</td>
#     </tr>
#     <tr>
#       <th id="T_90fe4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_90fe4_row7_col0" class="data row7 col0" >39.200000</td>
#       <td id="T_90fe4_row7_col1" class="data row7 col1" >19.600000</td>
#       <td id="T_90fe4_row7_col2" class="data row7 col2" >195.000000</td>
#       <td id="T_90fe4_row7_col3" class="data row7 col3" >4675.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Row/Column/Tablewise application: `.apply()`

# %% [markdown]
# Let’s see how we could do the same formatting using `.apply()`:

# %%
def highlight_190(series):
    green = 'background-color: lightgreen'
    pink = 'background-color: pink; color: white'
    return [green if value > 190 else pink for value in series]

df_num.style.apply(highlight_190)
# Out:
# <style type="text/css">
# #T_f303c_row0_col0, #T_f303c_row0_col1, #T_f303c_row0_col2, #T_f303c_row1_col0, #T_f303c_row1_col1, #T_f303c_row1_col2, #T_f303c_row2_col0, #T_f303c_row2_col1, #T_f303c_row3_col0, #T_f303c_row3_col1, #T_f303c_row3_col2, #T_f303c_row3_col3, #T_f303c_row4_col0, #T_f303c_row4_col1, #T_f303c_row5_col0, #T_f303c_row5_col1, #T_f303c_row5_col2, #T_f303c_row6_col0, #T_f303c_row6_col1, #T_f303c_row6_col2, #T_f303c_row7_col0, #T_f303c_row7_col1 {
#   background-color: pink;
#   color: white;
# }
# #T_f303c_row0_col3, #T_f303c_row1_col3, #T_f303c_row2_col2, #T_f303c_row2_col3, #T_f303c_row4_col2, #T_f303c_row4_col3, #T_f303c_row5_col3, #T_f303c_row6_col3, #T_f303c_row7_col2, #T_f303c_row7_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f303c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f303c_level0_col0" class="col_heading level0 col0" >length</th>
#       <th id="T_f303c_level0_col1" class="col_heading level0 col1" >depth</th>
#       <th id="T_f303c_level0_col2" class="col_heading level0 col2" >flipper</th>
#       <th id="T_f303c_level0_col3" class="col_heading level0 col3" >mass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f303c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f303c_row0_col0" class="data row0 col0" >39.100000</td>
#       <td id="T_f303c_row0_col1" class="data row0 col1" >18.700000</td>
#       <td id="T_f303c_row0_col2" class="data row0 col2" >181.000000</td>
#       <td id="T_f303c_row0_col3" class="data row0 col3" >3750.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f303c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f303c_row1_col0" class="data row1 col0" >39.500000</td>
#       <td id="T_f303c_row1_col1" class="data row1 col1" >17.400000</td>
#       <td id="T_f303c_row1_col2" class="data row1 col2" >186.000000</td>
#       <td id="T_f303c_row1_col3" class="data row1 col3" >3800.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f303c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f303c_row2_col0" class="data row2 col0" >40.300000</td>
#       <td id="T_f303c_row2_col1" class="data row2 col1" >18.000000</td>
#       <td id="T_f303c_row2_col2" class="data row2 col2" >195.000000</td>
#       <td id="T_f303c_row2_col3" class="data row2 col3" >3250.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f303c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f303c_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_f303c_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_f303c_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_f303c_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f303c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f303c_row4_col0" class="data row4 col0" >36.700000</td>
#       <td id="T_f303c_row4_col1" class="data row4 col1" >19.300000</td>
#       <td id="T_f303c_row4_col2" class="data row4 col2" >193.000000</td>
#       <td id="T_f303c_row4_col3" class="data row4 col3" >3450.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f303c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f303c_row5_col0" class="data row5 col0" >39.300000</td>
#       <td id="T_f303c_row5_col1" class="data row5 col1" >20.600000</td>
#       <td id="T_f303c_row5_col2" class="data row5 col2" >190.000000</td>
#       <td id="T_f303c_row5_col3" class="data row5 col3" >3650.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f303c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f303c_row6_col0" class="data row6 col0" >38.900000</td>
#       <td id="T_f303c_row6_col1" class="data row6 col1" >17.800000</td>
#       <td id="T_f303c_row6_col2" class="data row6 col2" >181.000000</td>
#       <td id="T_f303c_row6_col3" class="data row6 col3" >3625.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f303c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f303c_row7_col0" class="data row7 col0" >39.200000</td>
#       <td id="T_f303c_row7_col1" class="data row7 col1" >19.600000</td>
#       <td id="T_f303c_row7_col2" class="data row7 col2" >195.000000</td>
#       <td id="T_f303c_row7_col3" class="data row7 col3" >4675.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can also chain them just like the previous functions:

# %%
(df_num
 .style
 .apply(highlight_190)
 .applymap(
     lambda value: 'opacity: 40%' if value < 30 else None)
)
# Out:
# <style type="text/css">
# #T_ff258_row0_col0, #T_ff258_row0_col2, #T_ff258_row1_col0, #T_ff258_row1_col2, #T_ff258_row2_col0, #T_ff258_row3_col0, #T_ff258_row3_col1, #T_ff258_row3_col2, #T_ff258_row3_col3, #T_ff258_row4_col0, #T_ff258_row5_col0, #T_ff258_row5_col2, #T_ff258_row6_col0, #T_ff258_row6_col2, #T_ff258_row7_col0 {
#   background-color: pink;
#   color: white;
# }
# #T_ff258_row0_col1, #T_ff258_row1_col1, #T_ff258_row2_col1, #T_ff258_row4_col1, #T_ff258_row5_col1, #T_ff258_row6_col1, #T_ff258_row7_col1 {
#   background-color: pink;
#   color: white;
#   opacity: 40%;
# }
# #T_ff258_row0_col3, #T_ff258_row1_col3, #T_ff258_row2_col2, #T_ff258_row2_col3, #T_ff258_row4_col2, #T_ff258_row4_col3, #T_ff258_row5_col3, #T_ff258_row6_col3, #T_ff258_row7_col2, #T_ff258_row7_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ff258">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff258_level0_col0" class="col_heading level0 col0" >length</th>
#       <th id="T_ff258_level0_col1" class="col_heading level0 col1" >depth</th>
#       <th id="T_ff258_level0_col2" class="col_heading level0 col2" >flipper</th>
#       <th id="T_ff258_level0_col3" class="col_heading level0 col3" >mass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff258_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff258_row0_col0" class="data row0 col0" >39.100000</td>
#       <td id="T_ff258_row0_col1" class="data row0 col1" >18.700000</td>
#       <td id="T_ff258_row0_col2" class="data row0 col2" >181.000000</td>
#       <td id="T_ff258_row0_col3" class="data row0 col3" >3750.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff258_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ff258_row1_col0" class="data row1 col0" >39.500000</td>
#       <td id="T_ff258_row1_col1" class="data row1 col1" >17.400000</td>
#       <td id="T_ff258_row1_col2" class="data row1 col2" >186.000000</td>
#       <td id="T_ff258_row1_col3" class="data row1 col3" >3800.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff258_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ff258_row2_col0" class="data row2 col0" >40.300000</td>
#       <td id="T_ff258_row2_col1" class="data row2 col1" >18.000000</td>
#       <td id="T_ff258_row2_col2" class="data row2 col2" >195.000000</td>
#       <td id="T_ff258_row2_col3" class="data row2 col3" >3250.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff258_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ff258_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_ff258_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_ff258_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_ff258_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ff258_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ff258_row4_col0" class="data row4 col0" >36.700000</td>
#       <td id="T_ff258_row4_col1" class="data row4 col1" >19.300000</td>
#       <td id="T_ff258_row4_col2" class="data row4 col2" >193.000000</td>
#       <td id="T_ff258_row4_col3" class="data row4 col3" >3450.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff258_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ff258_row5_col0" class="data row5 col0" >39.300000</td>
#       <td id="T_ff258_row5_col1" class="data row5 col1" >20.600000</td>
#       <td id="T_ff258_row5_col2" class="data row5 col2" >190.000000</td>
#       <td id="T_ff258_row5_col3" class="data row5 col3" >3650.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff258_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ff258_row6_col0" class="data row6 col0" >38.900000</td>
#       <td id="T_ff258_row6_col1" class="data row6 col1" >17.800000</td>
#       <td id="T_ff258_row6_col2" class="data row6 col2" >181.000000</td>
#       <td id="T_ff258_row6_col3" class="data row6 col3" >3625.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff258_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ff258_row7_col0" class="data row7 col0" >39.200000</td>
#       <td id="T_ff258_row7_col1" class="data row7 col1" >19.600000</td>
#       <td id="T_ff258_row7_col2" class="data row7 col2" >195.000000</td>
#       <td id="T_ff258_row7_col3" class="data row7 col3" >4675.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# It’s useful to know how to use both `.apply()` and `.applymap()`. Here’s an example where we can use `.apply()` but not `.applymap()`:

# %%
def highlight_above_median(series):
    is_above = series > series.median()
    above = 'background-color: lightgreen'
    below = 'background-color: grey; color: white'
    return [above if value else below for value in is_above]

df_num.style.apply(highlight_above_median)
# Out:
# <style type="text/css">
# #T_2366b_row0_col0, #T_2366b_row0_col1, #T_2366b_row0_col2, #T_2366b_row1_col1, #T_2366b_row1_col2, #T_2366b_row2_col1, #T_2366b_row2_col3, #T_2366b_row3_col0, #T_2366b_row3_col1, #T_2366b_row3_col2, #T_2366b_row3_col3, #T_2366b_row4_col0, #T_2366b_row4_col3, #T_2366b_row5_col2, #T_2366b_row5_col3, #T_2366b_row6_col0, #T_2366b_row6_col1, #T_2366b_row6_col2, #T_2366b_row6_col3, #T_2366b_row7_col0 {
#   background-color: grey;
#   color: white;
# }
# #T_2366b_row0_col3, #T_2366b_row1_col0, #T_2366b_row1_col3, #T_2366b_row2_col0, #T_2366b_row2_col2, #T_2366b_row4_col1, #T_2366b_row4_col2, #T_2366b_row5_col0, #T_2366b_row5_col1, #T_2366b_row7_col1, #T_2366b_row7_col2, #T_2366b_row7_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2366b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2366b_level0_col0" class="col_heading level0 col0" >length</th>
#       <th id="T_2366b_level0_col1" class="col_heading level0 col1" >depth</th>
#       <th id="T_2366b_level0_col2" class="col_heading level0 col2" >flipper</th>
#       <th id="T_2366b_level0_col3" class="col_heading level0 col3" >mass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2366b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2366b_row0_col0" class="data row0 col0" >39.100000</td>
#       <td id="T_2366b_row0_col1" class="data row0 col1" >18.700000</td>
#       <td id="T_2366b_row0_col2" class="data row0 col2" >181.000000</td>
#       <td id="T_2366b_row0_col3" class="data row0 col3" >3750.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2366b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2366b_row1_col0" class="data row1 col0" >39.500000</td>
#       <td id="T_2366b_row1_col1" class="data row1 col1" >17.400000</td>
#       <td id="T_2366b_row1_col2" class="data row1 col2" >186.000000</td>
#       <td id="T_2366b_row1_col3" class="data row1 col3" >3800.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2366b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2366b_row2_col0" class="data row2 col0" >40.300000</td>
#       <td id="T_2366b_row2_col1" class="data row2 col1" >18.000000</td>
#       <td id="T_2366b_row2_col2" class="data row2 col2" >195.000000</td>
#       <td id="T_2366b_row2_col3" class="data row2 col3" >3250.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2366b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2366b_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_2366b_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_2366b_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_2366b_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2366b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2366b_row4_col0" class="data row4 col0" >36.700000</td>
#       <td id="T_2366b_row4_col1" class="data row4 col1" >19.300000</td>
#       <td id="T_2366b_row4_col2" class="data row4 col2" >193.000000</td>
#       <td id="T_2366b_row4_col3" class="data row4 col3" >3450.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2366b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2366b_row5_col0" class="data row5 col0" >39.300000</td>
#       <td id="T_2366b_row5_col1" class="data row5 col1" >20.600000</td>
#       <td id="T_2366b_row5_col2" class="data row5 col2" >190.000000</td>
#       <td id="T_2366b_row5_col3" class="data row5 col3" >3650.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2366b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2366b_row6_col0" class="data row6 col0" >38.900000</td>
#       <td id="T_2366b_row6_col1" class="data row6 col1" >17.800000</td>
#       <td id="T_2366b_row6_col2" class="data row6 col2" >181.000000</td>
#       <td id="T_2366b_row6_col3" class="data row6 col3" >3625.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2366b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2366b_row7_col0" class="data row7 col0" >39.200000</td>
#       <td id="T_2366b_row7_col1" class="data row7 col1" >19.600000</td>
#       <td id="T_2366b_row7_col2" class="data row7 col2" >195.000000</td>
#       <td id="T_2366b_row7_col3" class="data row7 col3" >4675.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We find the median value by each column and highlight values higher than median in green and the rest in grey. We can also style the entire column based on conditions with `.apply()`:

# %%
def highlight(data):
    n = len(data)
    if data['sex'] == 'Male':
        return n*['background-color: lightblue']
    if data['sex'] == 'Female':
        return n*['background-color: lightpink']
    else:
        return n*['']
    
df.head(6).style.apply(highlight, axis=1).hide_index()
# Out:
# C:\Users\johnw\AppData\Local\Temp\ipykernel_22236\3744408584.py:10: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   df.head(6).style.apply(highlight, axis=1).hide_index()
# <style type="text/css">
# #T_973f8_row0_col0, #T_973f8_row0_col1, #T_973f8_row0_col2, #T_973f8_row0_col3, #T_973f8_row0_col4, #T_973f8_row0_col5, #T_973f8_row0_col6, #T_973f8_row0_col7, #T_973f8_row5_col0, #T_973f8_row5_col1, #T_973f8_row5_col2, #T_973f8_row5_col3, #T_973f8_row5_col4, #T_973f8_row5_col5, #T_973f8_row5_col6, #T_973f8_row5_col7 {
#   background-color: lightblue;
# }
# #T_973f8_row1_col0, #T_973f8_row1_col1, #T_973f8_row1_col2, #T_973f8_row1_col3, #T_973f8_row1_col4, #T_973f8_row1_col5, #T_973f8_row1_col6, #T_973f8_row1_col7, #T_973f8_row2_col0, #T_973f8_row2_col1, #T_973f8_row2_col2, #T_973f8_row2_col3, #T_973f8_row2_col4, #T_973f8_row2_col5, #T_973f8_row2_col6, #T_973f8_row2_col7, #T_973f8_row4_col0, #T_973f8_row4_col1, #T_973f8_row4_col2, #T_973f8_row4_col3, #T_973f8_row4_col4, #T_973f8_row4_col5, #T_973f8_row4_col6, #T_973f8_row4_col7 {
#   background-color: lightpink;
# }
# </style>
# <table id="T_973f8">
#   <thead>
#     <tr>
#       <th id="T_973f8_level0_col0" class="col_heading level0 col0" >species</th>
#       <th id="T_973f8_level0_col1" class="col_heading level0 col1" >island</th>
#       <th id="T_973f8_level0_col2" class="col_heading level0 col2" >length</th>
#       <th id="T_973f8_level0_col3" class="col_heading level0 col3" >depth</th>
#       <th id="T_973f8_level0_col4" class="col_heading level0 col4" >flipper</th>
#       <th id="T_973f8_level0_col5" class="col_heading level0 col5" >mass</th>
#       <th id="T_973f8_level0_col6" class="col_heading level0 col6" >sex</th>
#       <th id="T_973f8_level0_col7" class="col_heading level0 col7" >predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_973f8_row0_col0" class="data row0 col0" >Adelie</td>
#       <td id="T_973f8_row0_col1" class="data row0 col1" >Torgersen</td>
#       <td id="T_973f8_row0_col2" class="data row0 col2" >39.100000</td>
#       <td id="T_973f8_row0_col3" class="data row0 col3" >18.700000</td>
#       <td id="T_973f8_row0_col4" class="data row0 col4" >181.000000</td>
#       <td id="T_973f8_row0_col5" class="data row0 col5" >3750.000000</td>
#       <td id="T_973f8_row0_col6" class="data row0 col6" >Male</td>
#       <td id="T_973f8_row0_col7" class="data row0 col7" >Adelie</td>
#     </tr>
#     <tr>
#       <td id="T_973f8_row1_col0" class="data row1 col0" >Adelie</td>
#       <td id="T_973f8_row1_col1" class="data row1 col1" >Torgersen</td>
#       <td id="T_973f8_row1_col2" class="data row1 col2" >39.500000</td>
#       <td id="T_973f8_row1_col3" class="data row1 col3" >17.400000</td>
#       <td id="T_973f8_row1_col4" class="data row1 col4" >186.000000</td>
#       <td id="T_973f8_row1_col5" class="data row1 col5" >3800.000000</td>
#       <td id="T_973f8_row1_col6" class="data row1 col6" >Female</td>
#       <td id="T_973f8_row1_col7" class="data row1 col7" >Adelie</td>
#     </tr>
#     <tr>
#       <td id="T_973f8_row2_col0" class="data row2 col0" >Adelie</td>
#       <td id="T_973f8_row2_col1" class="data row2 col1" >Torgersen</td>
#       <td id="T_973f8_row2_col2" class="data row2 col2" >40.300000</td>
#       <td id="T_973f8_row2_col3" class="data row2 col3" >18.000000</td>
#       <td id="T_973f8_row2_col4" class="data row2 col4" >195.000000</td>
#       <td id="T_973f8_row2_col5" class="data row2 col5" >3250.000000</td>
#       <td id="T_973f8_row2_col6" class="data row2 col6" >Female</td>
#       <td id="T_973f8_row2_col7" class="data row2 col7" >Adelie</td>
#     </tr>
#     <tr>
#       <td id="T_973f8_row3_col0" class="data row3 col0" >Adelie</td>
#       <td id="T_973f8_row3_col1" class="data row3 col1" >Torgersen</td>
#       <td id="T_973f8_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_973f8_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_973f8_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_973f8_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_973f8_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_973f8_row3_col7" class="data row3 col7" >Adelie</td>
#     </tr>
#     <tr>
#       <td id="T_973f8_row4_col0" class="data row4 col0" >Adelie</td>
#       <td id="T_973f8_row4_col1" class="data row4 col1" >Torgersen</td>
#       <td id="T_973f8_row4_col2" class="data row4 col2" >36.700000</td>
#       <td id="T_973f8_row4_col3" class="data row4 col3" >19.300000</td>
#       <td id="T_973f8_row4_col4" class="data row4 col4" >193.000000</td>
#       <td id="T_973f8_row4_col5" class="data row4 col5" >3450.000000</td>
#       <td id="T_973f8_row4_col6" class="data row4 col6" >Female</td>
#       <td id="T_973f8_row4_col7" class="data row4 col7" >Adelie</td>
#     </tr>
#     <tr>
#       <td id="T_973f8_row5_col0" class="data row5 col0" >Adelie</td>
#       <td id="T_973f8_row5_col1" class="data row5 col1" >Torgersen</td>
#       <td id="T_973f8_row5_col2" class="data row5 col2" >39.300000</td>
#       <td id="T_973f8_row5_col3" class="data row5 col3" >20.600000</td>
#       <td id="T_973f8_row5_col4" class="data row5 col4" >190.000000</td>
#       <td id="T_973f8_row5_col5" class="data row5 col5" >3650.000000</td>
#       <td id="T_973f8_row5_col6" class="data row5 col6" >Male</td>
#       <td id="T_973f8_row5_col7" class="data row5 col7" >Adelie</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Here, we have hidden DataFrame’s indices with `.hide_index()` for a cleaner look. If needed, you can also hide columns with `.hide_columns()` as well.

# %% [markdown]
# Lastly, most of these functions we looked at in this post take optional arguments to customise styling. The following two arguments are common and quite useful to know:
#
# - ️`axis` for along which axis to operate: columns, rows or the entire table
#
# - `subset` to select a subset of columns to style.

# %% [markdown]
# To learn more about styling, check out [this useful documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html) by pandas.
