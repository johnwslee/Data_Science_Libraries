# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Read In

# %%
df = pd.read_csv("data/diabetes_data_upload.csv")
df
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
# ...

# %%
# Setting RC parameters (figure size)
rc_params = {"figure.dpi": 120, "savefig.dpi": 300}
sns.set(rc_params)

# %% [markdown]
# # 1. Paired Bar Plot

# %%
sns.barplot(data=df,
            x="Polyuria",
            y="Age",
            hue="Gender",
            palette="husl")
plt.title("Polyuria Analysis Using Bar Plot")

# Place legend outside top right corner of plot
plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left", borderaxespad=0)
plt.show();

# %% [markdown]
# # 2. Count Plot

# %%
sns.countplot(data=df,
              y="Gender",
              hue="partial paresis",
              palette="flare")
plt.title("Count Plot for Partial Paresis")
plt.show();

# %% [markdown]
# # 3. Strip Plot

# %%
sns.stripplot(data=df,
              x="Age",
              y="visual blurring",
              hue="Gender",
              palette="cubehelix")
plt.title("Multivariant Analysis")
plt.show();

# %% [markdown]
# # 4. Swarm Plot

# %%
sns.catplot(data=df,
            x="weakness",
            y="Age",
            hue="Gender",
            kind="swarm",  # "strip", "swarm", "box", "violin", "boxen", "point", "bar", or "count"
            palette="Set2")
plt.title("Swarm Plot for Weakness")
plt.show();

# %% [markdown]
# # 5. Box Plot

# %%
sns.catplot(data=df,
            x="Obesity",
            y="Age",
            hue="Gender",
            kind="box",  # "strip", "swarm", "box", "violin", "boxen", "point", "bar", or "count"
            palette="pastel")
plt.title("Box Plot for Obesity")
plt.show();

# %% [markdown]
# # 6. Violin Plot

# %%
sns.catplot(data=df,
            x="delayed healing",
            y="Age",
            hue="Gender",
            kind="violin",  # "strip", "swarm", "box", "violin", "boxen", "point", "bar", or "count"
            palette="light:#5A9")
plt.title("Violin Plot for Delayed Healing")
plt.show();

# %%
sns.violinplot(data=df,
               x="delayed healing",
               y="Age",
               hue="Gender",
               palette="light:#5A9")
plt.title("Violin Plot for Delayed Healing")
plt.show();

# %% [markdown]
# # 7. Distribution Plot

# %%
sns.displot(data=df,
            x="Age",
            hue="Gender",
            col="Gender",
            palette="husl")
plt.title("Distibution Plot for Age")
plt.show();
