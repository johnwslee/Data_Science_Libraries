# %% [markdown]
# Original article is from [Medium](https://medium.com/towards-data-science/the-search-for-categorical-correlation-a1cf7f1888c9)

# %%
import pandas as pd
from dython.nominal import associations  # For Categorical Correlation

# %%
df = pd.read_csv("data/mushrooms.csv")

# %%
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.nunique()
# Out:
# class                        2
# cap-shape                    6
# cap-surface                  4
# cap-color                   10
# bruises                      2
# odor                         9
# gill-attachment              2
# gill-spacing                 2
# gill-size                    2
# gill-color                  12
# stalk-shape                  2
# stalk-root                   5
# stalk-surface-above-ring     4
# stalk-surface-below-ring     4
# stalk-color-above-ring       9
# stalk-color-below-ring       9
# veil-type                    1
# veil-color                   4
# ring-number                  3
# ring-type                    5
# spore-print-color            9
# population                   6
# habitat                      7
# dtype: int64

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
corr = associations(df, nom_nom_assoc='theil', figsize=(15, 15))

# %%
corr
# Out:
# {'corr':                              class  cap-shape  cap-surface  cap-color  \
#  class                     1.000000   0.048842     0.028617   0.036083
#  cap-shape                 0.029522   1.000000     0.030204   0.067283
#  cap-surface               0.018147   0.031688     1.000000   0.070244
#  cap-color                 0.014361   0.044305     0.044089   1.000000
#  bruises                   0.196440   0.057126     0.013462   0.041292
#  odor                      0.390648   0.080488     0.071845   0.245707
#  gill-attachment           0.081818   0.069684     0.186513   0.251221
#  gill-spacing              0.158154   0.007295     0.166868   0.193235
#  gill-size                 0.257946   0.098364     0.068052   0.202591
#  gill-color                0.137597   0.063356     0.063236   0.180369
#  stalk-shape               0.007616   0.085221     0.004689   0.310193
#  stalk-root                0.073957   0.164642     0.141559   0.255696
# ...
